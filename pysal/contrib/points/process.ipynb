# %% [markdown]
# # Point Processes
#
# **Author: Serge Rey <sjsrey@gmail.com>**
#
# ## Introduction
#
# * [What is a Point Process](#[What-is-a-Point-Process)
# * [Random Patterns](#Random-Patterns)
# * [Clustered Patterns](#Clustered-Patterns)

# %%
from process import PoissonPointProcess, PoissonClusterPointProcess
from window import Window, poly_from_bbox
import pysal as ps
from pysal.contrib import shapely_ext
#import shapely
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
va = ps.open(ps.examples.get_path("virginia.shp"))
polys = [shp for shp in va]
vapnts = ps.open(ps.examples.get_path("vapoints.shp"))
points = [shp for shp in vapnts]

# %%
# Create the exterior polygons for VA from the union of the county shapes
state = shapely_ext.cascaded_union(polys)

# %%
window = Window(state.parts)

# %%
# simulate a cluster process of size 200 with 10 parents and 20 children within 0.5 units of each parent. 1 realization
csamples = PoissonClusterPointProcess(window, 200, 10, 0.5, 1)
s0 = csamples.realizations[0]
plt.plot(s0[:,0], s0[:,1], '.')
plt.xlim(window.bbox[0],window.bbox[2])
plt.ylim(window.bbox[1],window.bbox[3])
# Out:
# (36.541481018066406, 39.45690155029297)

# %%
# simulate a cluster process of size 200 with 5 parents and 40 children within 0.5 units of each parent. 1 realization
csamples = PoissonClusterPointProcess(window, 200, 5, 0.5, 1)
s0 = csamples.realizations[0]
plt.plot(s0[:,0], s0[:,1], '.')
plt.xlim(window.bbox[0],window.bbox[2])
plt.ylim(window.bbox[1],window.bbox[3])
# Out:
# (36.541481018066406, 39.45690155029297)

# %%
# a csr process in the same window
samples = PoissonPointProcess(window, 200, 1)
s0 = samples.realizations[0]
plt.plot(s0[:,0], s0[:,1], '.')
plt.xlim(window.bbox[0],window.bbox[2])
plt.ylim(window.bbox[1],window.bbox[3])
# Out:
# (36.541481018066406, 39.45690155029297)

# %%
col = ps.open(ps.examples.get_path("columbus.shp"))
polys = [shp for shp in col]
colext = shapely_ext.cascaded_union(polys)
window = Window(colext.parts)

# %%
samples = PoissonPointProcess(window, 200, 1)
s0 = samples.realizations[0]
plt.plot(s0[:,0], s0[:,1], '.')
plt.xlim(window.bbox[0],window.bbox[2])
plt.ylim(window.bbox[1],window.bbox[3])
# Out:
# (10.788629531860352, 14.742449760437012)

# %%
# simulate a cluster process of size 200 with 10 parents and 20 children within 0.5 units of each parent. 1 realization
csamples = PoissonClusterPointProcess(window, 200, 10, 0.5, 1)
s0 = csamples.realizations[0]
plt.plot(s0[:,0], s0[:,1], '.')
plt.xlim(window.bbox[0],window.bbox[2])
plt.ylim(window.bbox[1],window.bbox[3])
# Out:
# (10.788629531860352, 14.742449760437012)

# %%
# simulate a cluster process of size 200 with 5 parents and 40 children within 0.5 units of each parent. 1 realization
csamples = PoissonClusterPointProcess(window, 200, 5, 0.5, 1)
s0 = csamples.realizations[0]
plt.plot(s0[:,0], s0[:,1], '.')
plt.xlim(window.bbox[0],window.bbox[2])
plt.ylim(window.bbox[1],window.bbox[3])
# Out:
# (10.788629531860352, 14.742449760437012)
