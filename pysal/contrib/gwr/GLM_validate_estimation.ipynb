# %%
#Import GLM and pysal
import os
import numpy as np
#os.chdir('/Users/qszhao/Dropbox/pysal/pysal/contrib/gwr')
os.chdir('/Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr')
from glm import GLM
import pysal
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
#Prepare some test data - columbus example
db = pysal.open(pysal.examples.get_path('columbus.dbf'),'r')
y = np.array(db.by_col("HOVAL"))
y = np.reshape(y, (49,1))
X = []
#X.append(np.ones(len(y)))
X.append(db.by_col("INC"))
X.append(db.by_col("CRIME"))
X = np.array(X).T
print X
# Out:
# [[ 19.531     15.72598 ]
#  [ 21.232     18.801754]
#  [ 15.956     30.626781]
#  [  4.477     32.38776 ]
#  [ 11.252     50.73151 ]
#  [ 16.028999  26.066658]
#  [  8.438      0.178269]
#  [ 11.337     38.425858]
#  [ 17.586     30.515917]
#  [ 13.598     34.000835]
#  [  7.467     62.275448]
#  [ 10.048     56.705669]
#  [  9.549     46.716129]
#  [  9.963     57.066132]
#  [  9.873     48.585487]
#  [  7.625     54.838711]
#  [  9.798     36.868774]
#  [ 13.185     43.962486]
#  [ 11.618     54.521965]
#  [ 31.07       0.223797]
#  [ 10.655     40.074074]
#  [ 11.709     33.705048]
#  [ 21.155001  20.048504]
#  [ 14.236     38.297871]
#  [  8.461     61.299175]
#  [  8.085     40.969742]
#  [ 10.822     52.79443 ]
#  [  7.856     56.919785]
#  [  8.681     60.750446]
#  [ 13.906     68.892044]
#  [ 16.940001  17.677214]
#  [ 18.941999  19.145592]
#  [  9.918     41.968163]
#  [ 14.948     23.974028]
#  [ 12.814     39.175053]
#  [ 18.739     14.305556]
#  [ 17.017     42.445076]
#  [ 11.107     53.710938]
#  [ 18.476999  19.100863]
#  [ 29.833     16.241299]
#  [ 22.207001  18.905146]
#  [ 25.872999  16.49189 ]
#  [ 13.38      36.663612]
#  [ 16.961     25.962263]
#  [ 14.135     29.028488]
#  [ 18.323999  16.530533]
#  [ 18.950001  27.822861]
#  [ 11.813     26.645266]
#  [ 18.796     22.541491]]

# %%
#First fit pysal OLS model
from pysal.spreg import ols
OLS = ols.OLS(y, X)
print OLS.betas
# Out:
# [[ 46.42818268]
#  [  0.62898397]
#  [ -0.48488854]]

# %%
#Then fit Gaussian GLM

#create Gaussian GLM model object
model = GLM(y, X, 'Gaussian')
model

#Fit model to estimate coefficients and return GLMResults object
results = model.fit()

#Check coefficients - R betas [46.4282, 0.6290, -0.4849]
print results.betas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f34ff89d7352> in <module>()
#       6
#       7 #Fit model to estimate coefficients and return GLMResults object
# ----> 8 results = model.fit()
#       9
#      10 #Check coefficients - R betas [46.4282, 0.6290, -0.4849]
#
# /Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr/glm.py in fit(self, ini_betas, tol, max_iter, solve)
#     105             ey = self.y/self.offset
#     106             if self.family == 'Gaussian':
# --> 107                 results = GLMResults(self, *gauss_iwls(self))
#     108             if self.family == 'Poisson':
#     109                 results =  GLMResults(self, *poiss_iwls(self))
#
# /Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr/glm_fits.py in gauss_iwls(GLM)
#       7     betas, w, v, n_iter = iwls(GLM.x, GLM.y, g_ey, link_g, GLM.family, GLM.offset,
#       8             GLM.y_fix, GLM.fit_params['ini_betas'],
# ----> 9             GLM.fit_params['tol'], GLM.fit_params['max_iter'])
#      10     GLM.fit_params['n_iter'] = n_iter
#      11     predy = get_y_hat(GLM.family, v, GLM.offset, GLM.y_fix)
#
# TypeError: iwls() takes at most 9 arguments (10 given)

# %%
# Gaussian GLM results from statsmodels
sm_results = smf.OLS(y, sm.add_constant(X), ).fit()
print sm_results.params
# Out:
# [ 46.42818268   0.62898397  -0.48488854]

# %%
#check other diagnostics; need to be added!

# %%
#Now fit a Poisson GLM 

poisson_y = np.round(y)

#create Poisson GLM model object
model = GLM(y, X, 'Poisson')
model

#Fit model to estimate coefficients and return GLMResults object
results = model.fit()

#Check coefficients - R betas [3.91926, 0.01198, -0.01371]
results.betas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a884e9d31376> in <module>()
#       8
#       9 #Fit model to estimate coefficients and return GLMResults object
# ---> 10 results = model.fit()
#      11
#      12 #Check coefficients - R betas [3.91926, 0.01198, -0.01371]
#
# /Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr/glm.py in fit(self, ini_betas, tol, max_iter, solve)
#     107                 results = GLMResults(self, *gauss_iwls(self))
#     108             if self.family == 'Poisson':
# --> 109                 results =  GLMResults(self, *poiss_iwls(self))
#     110             if self.family == 'logistic':
#     111                 results = GLMResults(self, *logit_iwls(self))
#
# /Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr/glm_fits.py in poiss_iwls(GLM)
#      17     betas, w, v, n_iter = iwls(GLM.x, GLM.y, g_ey, link_p, GLM.family, GLM.offset,
#      18             GLM.y_fix, GLM.fit_params['ini_betas'],
# ---> 19             GLM.fit_params['tol'], GLM.fit_params['max_iter'])
#      20     GLM.fit_params['n_iter'] = n_iter
#      21     predy = get_y_hat(GLM.family, v, GLM.offset, GLM.y_fix)
#
# TypeError: iwls() takes at most 9 arguments (10 given)

# %%
# Poisson GLM results from statsmodels
sm_results = smf.GLM(y, sm.add_constant(X), family=sm.families.Poisson()).fit()
print sm_results.params
# Out:
# [ 3.91925951  0.01198275 -0.0137072 ]

# %%
#Now fit a binomial GLM
londonhp = pd.read_csv('/Users/toshan/projects/londonhp.csv')
#londonhp = pd.read_csv('/Users/qszhao/Dropbox/pysal/pysal/contrib/gwr/londonhp.csv')
y = londonhp['BATH2'].values
y = np.reshape(y, (316,1))
X = londonhp['FLOORSZ'].values
X = np.reshape(X, (316,1))

#create logistic GLM model object
model = GLM(y, X, 'logistic')
model

#Fit model to estimate coefficients and return GLMResults object
results = model.fit()

#Check coefficients - R betas [-5.33638, 0.02878]
#results.betas
# Out:
# [[ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [-2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]
#  [ 2.33075597]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-9529971bb697> in <module>()
#      12
#      13 #Fit model to estimate coefficients and return GLMResults object
# ---> 14 results = model.fit()
#      15
#      16 #Check coefficients - R betas [-5.33638, 0.02878]
#
# /Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr/glm.pyc in fit(self, ini_betas, tol, max_iter, solve)
#     109                 results =  GLMResults(self, *poiss_iwls(self))
#     110             if self.family == 'logistic':
# --> 111                 results = GLMResults(self, *logit_iwls(self))
#     112         return results
#     113
#
# /Users/toshan/projects/GIS596/pysal/pysal/contrib/gwr/glm_fits.py in logit_iwls(GLM)
#      33     betas, w, v, n_iter = iwls(GLM.x, GLM.y, g_ey, link_l, GLM.family, GLM.offset,
#      34             GLM.y_fix, GLM.fit_params['ini_betas'],
# ---> 35             GLM.fit_params['tol'], GLM.fit_params['max_iter'])
#      36     GLM.fit_params['n_iter'] = n_iter
#      37     predy = get_y_hat(GLM.family, v, GLM.offset, GLM.y_fix)
#
# TypeError: iwls() takes at most 9 arguments (10 given)

# %%
# Logistic GLM results from statsmodels
sm_results = smf.GLM(y, sm.add_constant(X), family=sm.families.Binomial()).fit()
print sm_results.params
# Out:
# [-5.33638276  0.0287754 ]

# %%
print X
# Out:
# [[ 77]
#  [ 75]
#  [ 64]
#  [ 95]
#  [107]
#  [100]
#  [ 81]
#  [151]
#  [ 98]
#  [260]
#  [171]
#  [161]
#  [ 91]
#  [ 80]
#  [ 50]
#  [ 85]
#  [ 52]
#  [ 69]
#  [ 60]
#  [ 84]
#  [155]
#  [ 97]
#  [ 69]
#  [126]
#  [ 90]
#  [ 43]
#  [ 51]
#  [ 41]
#  [140]
#  [ 80]
#  [ 52]
#  [ 86]
#  [ 66]
#  [ 60]
#  [ 40]
#  [155]
#  [138]
#  [ 97]
#  [115]
#  [148]
#  [206]
#  [ 60]
#  [ 53]
#  [ 96]
#  [ 88]
#  [160]
#  [ 31]
#  [ 43]
#  [154]
#  [ 60]
#  [131]
#  [ 60]
#  [ 46]
#  [ 61]
#  [125]
#  [150]
#  [ 76]
#  [ 92]
#  [ 96]
#  [100]
#  [105]
#  [ 72]
#  [ 48]
#  [ 41]
#  [ 72]
#  [ 65]
#  [ 60]
#  [ 65]
#  [ 98]
#  [ 33]
#  [144]
#  [111]
#  [ 91]
#  [108]
#  [ 38]
#  [ 48]
#  [ 95]
#  [ 63]
#  [ 98]
#  [129]
#  [108]
#  [ 51]
#  [131]
#  [ 66]
#  [ 48]
#  [127]
#  [ 76]
#  [ 68]
#  [ 52]
#  [ 64]
#  [ 57]
#  [121]
#  [ 67]
#  [ 76]
#  [112]
#  [ 96]
#  [ 90]
#  [ 53]
#  [ 93]
#  [ 64]
#  [ 97]
#  [ 58]
#  [ 44]
#  [157]
#  [ 53]
#  [ 70]
#  [ 71]
#  [167]
#  [ 47]
#  [ 70]
#  [ 96]
#  [ 77]
#  [ 75]
#  [ 71]
#  [ 67]
#  [ 47]
#  [ 71]
#  [ 90]
#  [ 69]
#  [ 64]
#  [ 65]
#  [ 95]
#  [ 60]
#  [ 60]
#  [ 65]
#  [ 54]
#  [121]
#  [105]
#  [ 50]
#  [ 85]
#  [ 69]
#  [ 69]
#  [ 62]
#  [ 65]
#  [ 93]
#  [ 93]
#  [ 70]
#  [ 62]
#  [155]
#  [ 68]
#  [117]
#  [ 80]
#  [ 80]
#  [ 75]
#  [ 98]
#  [114]
#  [ 86]
#  [ 70]
#  [ 50]
#  [ 51]
#  [163]
#  [124]
#  [ 59]
#  [ 95]
#  [ 51]
#  [ 63]
#  [ 85]
#  [ 53]
#  [ 46]
#  [102]
#  [114]
#  [ 83]
#  [ 47]
#  [ 40]
#  [ 63]
#  [123]
#  [100]
#  [ 63]
#  [110]
#  [ 79]
#  [ 98]
#  [ 99]
#  [120]
#  [ 52]
#  [ 48]
#  [ 37]
#  [ 81]
#  [ 30]
#  [ 88]
#  [ 50]
#  [ 35]
#  [116]
#  [ 67]
#  [ 45]
#  [ 80]
#  [ 86]
#  [109]
#  [ 59]
#  [ 75]
#  [ 60]
#  [ 71]
#  [141]
#  [121]
#  [ 50]
#  [168]
#  [ 90]
#  [ 51]
#  [133]
#  [ 75]
#  [133]
#  [127]
#  [ 37]
#  [ 68]
#  [105]
#  [ 61]
#  [123]
#  [151]
#  [110]
#  [ 77]
#  [220]
#  [ 94]
#  [ 77]
#  [ 70]
#  [100]
#  [ 98]
#  [126]
#  [ 55]
#  [105]
#  [ 60]
#  [176]
#  [104]
#  [ 68]
#  [ 62]
#  [ 70]
#  [ 48]
#  [102]
#  [ 80]
#  [ 97]
#  [ 66]
#  [ 80]
#  [102]
#  [160]
#  [ 55]
#  [ 60]
#  [ 71]
#  [125]
#  [ 85]
#  [ 85]
#  [190]
#  [137]
#  [ 48]
#  [ 41]
#  [ 42]
#  [ 51]
#  [ 57]
#  [ 60]
#  [114]
#  [ 88]
#  [ 84]
#  [108]
#  [ 66]
#  [ 85]
#  [ 42]
#  [ 98]
#  [ 90]
#  [127]
#  [100]
#  [ 55]
#  [ 76]
#  [ 82]
#  [ 63]
#  [ 80]
#  [ 71]
#  [ 76]
#  [121]
#  [109]
#  [ 92]
#  [160]
#  [109]
#  [185]
#  [100]
#  [ 90]
#  [ 90]
#  [ 86]
#  [ 88]
#  [ 95]
#  [116]
#  [135]
#  [ 61]
#  [ 74]
#  [ 60]
#  [235]
#  [ 76]
#  [ 66]
#  [100]
#  [ 49]
#  [ 50]
#  [ 37]
#  [100]
#  [ 88]
#  [ 90]
#  [ 52]
#  [ 95]
#  [ 81]
#  [ 79]
#  [ 96]
#  [ 75]
#  [ 91]
#  [ 86]
#  [ 83]
#  [180]
#  [108]
#  [ 80]
#  [ 96]
#  [ 49]
#  [117]
#  [117]
#  [ 86]
#  [ 46]
#  [ 66]
#  [ 95]
#  [ 57]
#  [120]
#  [137]
#  [ 68]
#  [240]]
