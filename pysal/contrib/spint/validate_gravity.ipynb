# %%
import numpy as np
import pandas as pd

from gravity import Gravity, Production, Attraction, Doubly

# %%
f = np.array([0, 6469, 7629, 20036, 4690,
                        6194, 11688, 2243, 8857, 7248,
                        3559, 9221, 10099, 22866, 3388,
                        9986, 46618, 11639, 1380, 5261,
                        5985, 6731, 2704, 12250, 16132])
o = np.repeat(1, 25)
d = np.array(range(1, 26))
dij = np.array([0, 576, 946, 597, 373,
                        559, 707, 1208, 602, 692,
                        681, 1934, 332, 595, 906,
                        425, 755, 672, 1587, 526,
                        484, 2141, 2182, 410, 540])
pop = np.array([1596000, 2071000, 3376000, 6978000, 1345000,
                        2064000, 2378000, 1239000, 4435000, 1999000,
                        1274000, 7042000, 834000, 1268000, 1965000,
                        1046000, 12131000, 4824000, 969000, 2401000,
                        2410000, 2847000, 1425000, 1089000, 2909000])
dt = pd.DataFrame({'o': o,
                            'd': d,
                            'pop': pop,
                            'dij': dij,
                            'f': f})


dt1 = dt[dt['o'] != dt['d']]

# %%
production = Production(dt1, 'f' , 'o', 'd', ['pop'], 'dij', 'pow')
results = production.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   24
# Model:                            GLM   Df Residuals:                       21
# Model Family:                 Poisson   Df Model:                            2
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -32360.
# Date:                Tue, 24 May 2016   Deviance:                       64461.
# Time:                        19:49:33   Pearson chi2:                 8.04e+04
# No. Iterations:                     9
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.2337      0.022     55.475      0.000         1.190     1.277
# x1             1.2337      0.022     55.475      0.000         1.190     1.277
# x2             0.7818      0.003    282.501      0.000         0.776     0.787
# x3            -0.7365      0.005   -139.641      0.000        -0.747    -0.726
# ==============================================================================
# """

# %%
f = np.array([0, 180048, 79223, 26887, 198144, 17995, 35563, 30528, 110792,
                        283049, 0, 300345, 67280, 718673, 55094, 93434, 87987, 268458,
                        87267, 237229, 0, 281791, 551483, 230788, 178517, 172711, 394481,
                        29877, 60681, 286580, 0, 143860, 49892, 185618, 181868, 274629,
                        130830, 382565, 346407, 92308, 0, 252189, 192223, 89389, 279739,
                        21434, 53772, 287340, 49828, 316650, 0, 141679, 27409, 87938,
                        30287, 64645, 161645, 144980, 199466, 121366, 0, 134229, 289880,
                        21450, 43749, 97808, 113683, 89806, 25574, 158006, 0, 437255,
                        72114, 133122, 229764, 165405, 266305, 66324, 252039, 342948, 0])
o = np.repeat(np.array(range(1, 10)), 9)
d = np.tile(np.array(range(1, 10)), 9)
dij = np.array([0, 219, 1009, 1514, 974, 1268, 1795, 2420, 3174,
                        219, 0, 831, 1336, 755, 1049, 1576, 2242, 2996,
                        1009, 831, 0, 505, 1019, 662, 933, 1451, 2205,
                        1514, 1336, 505, 0, 1370, 888, 654, 946, 1700,
                        974, 755, 1019, 1370, 0, 482, 1144, 2278, 2862,
                        1268, 1049, 662, 888, 482, 0, 662, 1795, 2380,
                        1795, 1576, 933, 654, 1144, 662, 0, 1287, 1779,
                        2420, 2242, 1451, 946, 2278, 1795, 1287, 0, 754,
                        3147, 2996, 2205, 1700, 2862, 2380, 1779, 754, 0])
dt = pd.DataFrame({'o': o,
                            'd': d,
                            'f': f,
                            'dij': dij})


dt2 = dt[dt['o'] != dt['d']]

# %%
doubly = Doubly(dt2, 'f' , 'o', 'd', 'dij', 'exp')
results = doubly.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   72
# Model:                            GLM   Df Residuals:                       54
# Model Family:                 Poisson   Df Model:                           17
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -3.8776e+05
# Date:                Tue, 24 May 2016   Deviance:                   7.7454e+05
# Time:                        19:49:34   Pearson chi2:                 7.86e+05
# No. Iterations:                   100
# ==============================================================================
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         10.4920      0.001    1.9e+04      0.000        10.491    10.493
# x1             0.5066      0.001    447.220      0.000         0.504     0.509
# x2             1.5032      0.001   2060.784      0.000         1.502     1.505
# x3             1.5561      0.001   2278.221      0.000         1.555     1.557
# x4             0.8677      0.001   1004.815      0.000         0.866     0.869
# x5             1.6532      0.001   2181.711      0.000         1.652     1.655
# x6             0.6215      0.001    653.310      0.000         0.620     0.623
# x7             0.9209      0.001   1039.259      0.000         0.919     0.923
# x8             0.7739      0.001    777.862      0.000         0.772     0.776
# x9             2.0888      0.001   2201.238      0.000         2.087     2.091
# x10            0.4502      0.001    396.405      0.000         0.448     0.452
# x11            1.0874      0.001   1212.461      0.000         1.086     1.089
# x12            1.4143      0.001   1913.613      0.000         1.413     1.416
# x13            0.6762      0.001    697.643      0.000         0.674     0.678
# x14            1.9051      0.001   2887.863      0.000         1.904     1.906
# x15            0.4812      0.001    464.213      0.000         0.479     0.483
# x16            1.0421      0.001   1213.251      0.000         1.040     1.044
# x17            0.9878      0.001   1039.205      0.000         0.986     0.990
# x18            2.4477      0.001   2744.226      0.000         2.446     2.449
# x19           -0.0007   5.16e-07  -1427.464      0.000        -0.001    -0.001
# ==============================================================================
# """
