# %%
from choroBrewer import choro
from pysal.contrib import pdio
import pysal as ps
# Out:
# /home/serge/Dropbox/p/pysal/src/pysal/pysal/core/IOHandlers/__init__.py:25: UserWarning: SQLAlchemy and Geomet not installed, database I/O disabled
#   warnings.warn('SQLAlchemy and Geomet not installed, database I/O disabled')
# brewer2mpl  not installed. Functionality related to it will not work
# ---------------------------------------------------
# NameError         Traceback (most recent call last)
# <ipython-input-1-85fbdfcb3412> in <module>()
# ----> 1 from choroBrewer import choro
#       2 from pysal.contrib import pdio
#       3 import pysal as ps
#
# /home/serge/Dropbox/p/pysal/src/pysal/pysal/contrib/viz/choroBrewer.py in <module>()
#       4 from ipywidgets import Dropdown, RadioButtons,  HBox, interact
#       5 from IPython.display import display
# ----> 6 from pysal.contrib.viz.color import color_display_types
#       7 from pysal.contrib.viz.color import plot_cmaps as pcmaps
#       8 from pysal.contrib.viz import mapping as maps
#
# ...

# %%
gd = pdio.read_files(ps.examples.get_path('south.shp'))

# %%
choro(gd, 'HR90')

# %%
choro(gd, 'HR90', show_cmaps=False, fig_size=(9,9))

# %%
choro(gd, 'HR90',  fig_size=(9,9))
