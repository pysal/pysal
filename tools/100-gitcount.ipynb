# %% [markdown]
# # PySAL Change Log Statistics

# %% [markdown]
# ## Approach
# - get date of last gh release of each package -> github_released
# - get date of last pypi release of each package -> pypi_released
# - get data of last meta-release -> start_date
# - for each package
#   - get issues between start_date and package_released in master/main
#   - get pulls between start_date and package_released in master/main

# %%
from release_info import (issues_closed_since, packages,
                          is_pull_request,
                          sorted_by_field,
                          clone_defaults
                         )
import datetime

# %%
packages
# Out:
# ['libpysal',
#  'access',
#  'esda',
#  'giddy',
#  'inequality',
#  'pointpats',
#  'segregation',
#  'spaghetti',
#  'mgwr',
#  'spglm',
#  'spint',
#  'spreg',
#  'spvcm',
#  'tobler',
#  'mapclassify',
#  'splot',
#  'spopt',
#  'pysal',
#  'pysal']

# %%
packages.append('pysal') # add meta package

# %%
clone_defaults(packages)
# Out:
# git clone --branch master https://github.com/pysal/libpysal.git tmp/libpysal
# git clone --branch master https://github.com/pysal/access.git tmp/access
# git clone --branch master https://github.com/pysal/esda.git tmp/esda
# git clone --branch master https://github.com/pysal/giddy.git tmp/giddy
# git clone --branch master https://github.com/pysal/inequality.git tmp/inequality
# git clone --branch master https://github.com/pysal/pointpats.git tmp/pointpats
# git clone --branch master https://github.com/pysal/segregation.git tmp/segregation
# git clone --branch main https://github.com/pysal/spaghetti.git tmp/spaghetti
# git clone --branch master https://github.com/pysal/mgwr.git tmp/mgwr
# git clone --branch master https://github.com/pysal/spglm.git tmp/spglm
# git clone --branch master https://github.com/pysal/spint.git tmp/spint
# git clone --branch master https://github.com/pysal/spreg.git tmp/spreg
# git clone --branch master https://github.com/pysal/spvcm.git tmp/spvcm
# git clone --branch master https://github.com/pysal/tobler.git tmp/tobler
# git clone --branch master https://github.com/pysal/mapclassify.git tmp/mapclassify
# git clone --branch main https://github.com/pysal/splot.git tmp/splot
# git clone --branch main https://github.com/pysal/spopt.git tmp/spopt
# git clone --branch master https://github.com/pysal/pysal.git tmp/pysal
# git clone --branch master https://github.com/pysal/pysal.git tmp/pysal
# git clone --branch master https://github.com/pysal/pysal.git tmp/pysal

# %%
release_date = '2021-07-31'
start_date = '2021-01-31'
since_date = '--since="{start}"'.format(start=start_date)
since_date
since = datetime.datetime.strptime(start_date+" 0:0:0", "%Y-%m-%d %H:%M:%S")
since
# Out:
# datetime.datetime(2021, 1, 31, 0, 0)

# %%
issues = {}
for package in packages:
    issues[package] = issues_closed_since(since, project=f'pysal/{package}')

# %%
pulls = {}
for package in packages:
    pulls[package] = issues_closed_since(since, project=f'pysal/{package}',
                                         pulls=True)

# %%
len(issues)
# Out:
# 18

# %%
len(pulls)
# Out:
# 18

# %%
import pickle 

pickle.dump( issues, open( "issues_closed.p", "wb" ) )

pickle.dump( pulls, open("pulls_closed.p", "wb"))

# %%
len(issues['libpysal'])
# Out:
# 32

# %%
lps = issues['libpysal']

# %%
lps
# Out:
# [{'url': 'https://api.github.com/repos/pysal/libpysal/issues/421',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/421/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/421/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/421/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/421',
#   'id': 948081892,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjkyOTcxMzkw',
#   'number': 421,
#   'title': 'update Codecov action: major version only',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2181405394,
#     'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzk0',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/github_actions',
#     'name': 'github_actions',
#     'color': '000000',
#     'default': False,
#     'description': 'Pull requests that update Github_actions code'}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-07-19T22:39:27Z',
#   'updated_at': '2021-07-19T22:48:42Z',
#   'closed_at': '2021-07-19T22:48:42Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/421',
#    'html_url': 'https://github.com/pysal/libpysal/pull/421',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/421.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/421.patch'},
#   'body': 'Hello! Please make sure to check all these boxes before submitting a Pull Request\r\n(PR). Once you have checked the boxes, feel free to remove all text except the\r\njustification in point 5. \r\n\r\n1. [ ] You have run tests on this submission locally using `pytest` on your changes. Continuous integration will be run on all PRs with [GitHub Actions](https://github.com/pysal/libpysal/blob/master/.github/workflows/unittests.yml), but it is good practice to test changes locally prior to a making a PR.\r\n2. [ ] This pull request is directed to the `pysal/master` branch.\r\n3. [ ] This pull introduces new functionality covered by\r\n   [docstrings](https://en.wikipedia.org/wiki/Docstring#Python) and\r\n   [unittests](https://docs.python.org/2/library/unittest.html)? \r\n4. [ ] You have [assigned a\r\n   reviewer](https://help.github.com/articles/assigning-issues-and-pull-requests-to-other-github-users/) and added relevant [labels](https://help.github.com/articles/applying-labels-to-issues-and-pull-requests/)\r\n5. [ ] The justification for this PR is: \r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/418',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/418/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/418/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/418/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/418',
#   'id': 931029192,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc4NTg4Mjc1',
#   'number': 418,
#   'title': 'update conf.py',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1376367312,
#     'node_id': 'MDU6TGFiZWwxMzc2MzY3MzEy',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/docs',
#     'name': 'docs',
#     'color': 'ffc8b2',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 8,
#   'created_at': '2021-06-27T22:10:32Z',
#   'updated_at': '2021-06-28T00:34:59Z',
#   'closed_at': '2021-06-28T00:34:56Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/418',
#    'html_url': 'https://github.com/pysal/libpysal/pull/418',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/418.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/418.patch'},
#   'body': 'This PR resolves #417. We will need to regenerate the docs after merge.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/417',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/417/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/417/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/417/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/417',
#   'id': 931011547,
#   'node_id': 'MDU6SXNzdWU5MzEwMTE1NDc=',
#   'number': 417,
#   'title': 'notebooks links in tutorials broken',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1376367312,
#     'node_id': 'MDU6TGFiZWwxMzc2MzY3MzEy',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/docs',
#     'name': 'docs',
#     'color': 'ffc8b2',
#     'default': False,
#     'description': ''},
#    {'id': 536186560,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NjA=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/help%20wanted',
#     'name': 'help wanted',
#     'color': '128A0C',
#     'default': True,
#     'description': None},
#    {'id': 2663620474,
#     'node_id': 'MDU6TGFiZWwyNjYzNjIwNDc0',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/priority:%20high',
#     'name': 'priority: high',
#     'color': 'ADCA10',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-06-27T20:26:35Z',
#   'updated_at': '2021-06-28T00:34:56Z',
#   'closed_at': '2021-06-28T00:34:56Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'It appears the some behavior in `Jinja`/`nbsphinx` has changed and now the links that are included at the top of tutorials don\'t work to send back to the original notebook ("This page was generated from `notebooks/xxxx.ipynb`"). This is affecting all submodules that rebuilt docs recently (libpysal, spaghetti, spopt, esda). To see that is was previously successful, see [spreg](https://pysal.org/spreg/notebooks/GM_Lag_example.html), which docs haven\'t been rebuild recently. The problem seems to be in the [`set docname`](https://github.com/pysal/libpysal/blob/ed19d4f3151201cd1cf8fcfa423c2b7837fea56f/docs/conf.py#L294) statement within `nbsphinx_prolog`, but I haven\'t been able to figure out how to correct the bad link generation. \r\n\r\nAn example:\r\n* previously generated:\r\n  * https://github.com/pysal/spopt/blob/main/notebooks/reg-k-means.ipynb\r\n* currently generated:\r\n  * https://github.com/pysal/spopt//home/runner/work/spopt/spopt/docs/notebooks/reg-k-means.ipynb\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/416',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/416/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/416/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/416/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/416',
#   'id': 930993975,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc4NTYyOTQ5',
#   'number': 416,
#   'title': 'Fix name of examples notebook.',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-06-27T18:42:56Z',
#   'updated_at': '2021-06-28T00:19:23Z',
#   'closed_at': '2021-06-28T00:19:23Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/416',
#    'html_url': 'https://github.com/pysal/libpysal/pull/416',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/416.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/416.patch'},
#   'body': "The name got changed previously and now the example notebook isn't showing up: https://pysal.org/libpysal/tutorial.html",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/412',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/412/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/412/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/412/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/412',
#   'id': 924556110,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjczMTc4Mzky',
#   'number': 412,
#   'title': 'Add missing endianness in WK1 reader.',
#   'user': {'login': 'QuLogic',
#    'id': 302469,
#    'node_id': 'MDQ6VXNlcjMwMjQ2OQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/302469?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/QuLogic',
#    'html_url': 'https://github.com/QuLogic',
#    'followers_url': 'https://api.github.com/users/QuLogic/followers',
#    'following_url': 'https://api.github.com/users/QuLogic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/QuLogic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/QuLogic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/QuLogic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/QuLogic/orgs',
#    'repos_url': 'https://api.github.com/users/QuLogic/repos',
#    'events_url': 'https://api.github.com/users/QuLogic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/QuLogic/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-18T05:30:06Z',
#   'updated_at': '2021-06-27T19:00:32Z',
#   'closed_at': '2021-06-27T15:43:36Z',
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/412',
#    'html_url': 'https://github.com/pysal/libpysal/pull/412',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/412.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/412.patch'},
#   'body': '1. [x] You have run tests on this submission locally using `pytest` on your changes. Continuous integration will be run on all PRs with [GitHub Actions](https://github.com/pysal/libpysal/blob/master/.github/workflows/unittests.yml), but it is good practice to test changes locally prior to a making a PR.\r\n2. [x] This pull request is directed to the `pysal/master` branch.\r\n3. [n/a] This pull introduces new functionality covered by\r\n   [docstrings](https://en.wikipedia.org/wiki/Docstring#Python) and\r\n   [unittests](https://docs.python.org/2/library/unittest.html)? \r\n4. [not possible] You have [assigned a\r\n   reviewer](https://help.github.com/articles/assigning-issues-and-pull-requests-to-other-github-users/) and added relevant [labels](https://help.github.com/articles/applying-labels-to-issues-and-pull-requests/)\r\n5. [x] The justification for this PR is: \r\n\r\nEverything else unpacks in little-endian, except this one call. This breaks reading on big-endian systems.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/413',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/413/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/413/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/413/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/413',
#   'id': 930981317,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc4NTUzMzMx',
#   'number': 413,
#   'title': 'Update unittests, etc',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2525923533,
#     'node_id': 'MDU6TGFiZWwyNTI1OTIzNTMz',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/ci',
#     'name': 'ci',
#     'color': 'ffc4dc',
#     'default': False,
#     'description': ''},
#    {'id': 2181405394,
#     'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzk0',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/github_actions',
#     'name': 'github_actions',
#     'color': '000000',
#     'default': False,
#     'description': 'Pull requests that update Github_actions code'}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2021-06-27T17:29:45Z',
#   'updated_at': '2021-06-27T18:25:28Z',
#   'closed_at': '2021-06-27T18:08:37Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/413',
#    'html_url': 'https://github.com/pysal/libpysal/pull/413',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/413.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/413.patch'},
#   'body': 'This PR:\r\n* adds Python 3.9 to testing schema\r\n* update and standardizes `unittests.yml` and `release_and_publish.yml`\r\n  * uses `micromamba` action for much speedier env resolves',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/415',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/415/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/415/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/415/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/415',
#   'id': 930988671,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njc4NTU4OTU1',
#   'number': 415,
#   'title': 'classify repo as Python',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280158628,
#     'node_id': 'MDU6TGFiZWwxMjgwMTU4NjI4',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/maintenance',
#     'name': 'maintenance',
#     'color': 'c2e0c6',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-27T18:11:56Z',
#   'updated_at': '2021-06-27T18:20:24Z',
#   'closed_at': '2021-06-27T18:20:22Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/415',
#    'html_url': 'https://github.com/pysal/libpysal/pull/415',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/415.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/415.patch'},
#   'body': 'This PR classifies the `libpysal` repo as Python for search search results.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/389',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/389/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/389/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/389/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/389',
#   'id': 799347863,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY2MDA2MDA4',
#   'number': 389,
#   'title': 'add docs action workflow',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1376367312,
#     'node_id': 'MDU6TGFiZWwxMzc2MzY3MzEy',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/docs',
#     'name': 'docs',
#     'color': 'ffc8b2',
#     'default': False,
#     'description': ''},
#    {'id': 2181405394,
#     'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzk0',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/github_actions',
#     'name': 'github_actions',
#     'color': '000000',
#     'default': False,
#     'description': 'Pull requests that update Github_actions code'}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 11,
#   'created_at': '2021-02-02T14:47:40Z',
#   'updated_at': '2021-06-27T17:49:14Z',
#   'closed_at': '2021-06-27T17:10:01Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/389',
#    'html_url': 'https://github.com/pysal/libpysal/pull/389',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/389.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/389.patch'},
#   'body': 'Following up with #387, this PR:\r\n* adds GHA for building docs when a release is [triggered](https://github.com/pysal/libpysal/blob/ea866112419bf0cfa44e1ccc613963e201aa5938/.github/workflows/release_and_publish.yml#L16) \r\n* cleans and the `docs/` directory and removes the `docsrc/` directory\r\n* updates `conf.py` and `Makefile`\r\n\r\nThis action will not run until a release is [triggered](https://github.com/pysal/libpysal/blob/ea866112419bf0cfa44e1ccc613963e201aa5938/.github/workflows/release_and_publish.yml#L16). After the first run of the workflow *Setting -> GitHub Pages -> Source* must be updated to `gh-pages/{root}`. Once this is done `pysal.org/libpysal` will be rebuilt automatically after each release.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/411',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/411/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/411/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/411/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/411',
#   'id': 919920761,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjY5MTQ1OTMx',
#   'number': 411,
#   'title': 'Return a dataframe with info on available datasets',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-06-14T00:57:43Z',
#   'updated_at': '2021-06-27T15:56:28Z',
#   'closed_at': '2021-06-27T15:56:28Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/411',
#    'html_url': 'https://github.com/pysal/libpysal/pull/411',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/411.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/411.patch'},
#   'body': 'Addresses #282 \r\n\r\nReturn instead of print.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/409',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/409/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/409/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/409/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/409',
#   'id': 915065285,
#   'node_id': 'MDU6SXNzdWU5MTUwNjUyODU=',
#   'number': 409,
#   'title': 'Do not fetch examples on import',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1685679755,
#     'node_id': 'MDU6TGFiZWwxNjg1Njc5NzU1',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/examples',
#     'name': 'examples',
#     'color': '135699',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'sjsrey',
#     'id': 118042,
#     'node_id': 'MDQ6VXNlcjExODA0Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sjsrey',
#     'html_url': 'https://github.com/sjsrey',
#     'followers_url': 'https://api.github.com/users/sjsrey/followers',
#     'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#     'repos_url': 'https://api.github.com/users/sjsrey/repos',
#     'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-06-08T13:40:16Z',
#   'updated_at': '2021-06-14T00:33:22Z',
#   'closed_at': '2021-06-14T00:33:22Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'The GitHub Pages CDN issue this morning caused an interesting bug, breaking the import of libpysal.\r\n\r\nWe apparently call `poll_remotes()` on import, which failed today. I don\'t think we should do this unless a user wants datasets. `poll_remotes()` should be run once user requests `libpysal.examples.remote_datasets`, no sooner.\r\n\r\n```py\r\n~\\Miniconda3\\envs\\ox\\lib\\site-packages\\momepy\\utils.py in <module>\r\n      5 \r\n      6 import geopandas as gpd\r\n----> 7 import libpysal\r\n      8 import networkx as nx\r\n      9 import numpy as np\r\n\r\n~\\Miniconda3\\envs\\ox\\lib\\site-packages\\libpysal\\__init__.py in <module>\r\n     28 from . import io\r\n     29 from . import weights\r\n---> 30 from . import examples\r\n\r\n~\\Miniconda3\\envs\\ox\\lib\\site-packages\\libpysal\\examples\\__init__.py in <module>\r\n      4 \r\n      5 from .base import example_manager\r\n----> 6 from .remotes import datasets as remote_datasets\r\n      7 from .remotes import download as fetch_all\r\n      8 from .builtin import datasets as builtin_datasets\r\n\r\n~\\Miniconda3\\envs\\ox\\lib\\site-packages\\libpysal\\examples\\remotes.py in <module>\r\n     96 \r\n     97 \r\n---> 98 datasets = poll_remotes()\r\n     99 \r\n    100 \r\n\r\n~\\Miniconda3\\envs\\ox\\lib\\site-packages\\libpysal\\examples\\remotes.py in poll_remotes()\r\n     28     soup = BeautifulSoup(page.text, "html.parser")\r\n     29     samples = soup.find(class_="samples")\r\n---> 30     rows = samples.find_all("tr")\r\n     31     datasets = {}\r\n     32     for row in rows[1:]:\r\n\r\nAttributeError: \'NoneType\' object has no attribute \'find_all\'\r\n```\r\n\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/410',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/410/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/410/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/410/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/410',
#   'id': 919828947,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjY5MDc1NzEy',
#   'number': 410,
#   'title': 'Do not poll remotes on init.',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1685679755,
#     'node_id': 'MDU6TGFiZWwxNjg1Njc5NzU1',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/examples',
#     'name': 'examples',
#     'color': '135699',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2021-06-13T15:57:38Z',
#   'updated_at': '2021-06-13T20:37:28Z',
#   'closed_at': '2021-06-13T20:37:28Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/410',
#    'html_url': 'https://github.com/pysal/libpysal/pull/410',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/410.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/410.patch'},
#   'body': 'Addresses #409 ',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/400',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/400/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/400/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/400/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/400',
#   'id': 856654143,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NjE0MTk4NjQ1',
#   'number': 400,
#   'title': 'Fixed `index2da` causing inverted output',
#   'user': {'login': 'MgeeeeK',
#    'id': 40512095,
#    'node_id': 'MDQ6VXNlcjQwNTEyMDk1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40512095?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MgeeeeK',
#    'html_url': 'https://github.com/MgeeeeK',
#    'followers_url': 'https://api.github.com/users/MgeeeeK/followers',
#    'following_url': 'https://api.github.com/users/MgeeeeK/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MgeeeeK/gists{/gist_id}',
# ...
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-02-02T00:37:35Z',
#   'updated_at': '2021-02-02T04:05:48Z',
#   'closed_at': '2021-02-02T03:06:27Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/388',
#    'html_url': 'https://github.com/pysal/libpysal/pull/388',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/388.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/388.patch'},
#   'body': 'This PR updates the old "Getting Started" link in `README.rst` (http://pysal.org/getting_started#for-developers) for the link on the most recent iteration of pysal.org (https://pysal.org/docs/devs/).',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/387',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/387/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/387/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/387/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/387',
#   'id': 798103207,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY0OTczNjQx',
#   'number': 387,
#   'title': 'make build + make sync @docsrc',
#   'user': {'login': 'darribas',
#    'id': 417363,
#    'node_id': 'MDQ6VXNlcjQxNzM2Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/417363?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/darribas',
#    'html_url': 'https://github.com/darribas',
#    'followers_url': 'https://api.github.com/users/darribas/followers',
#    'following_url': 'https://api.github.com/users/darribas/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/darribas/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/darribas/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/darribas/subscriptions',
#    'organizations_url': 'https://api.github.com/users/darribas/orgs',
#    'repos_url': 'https://api.github.com/users/darribas/repos',
#    'events_url': 'https://api.github.com/users/darribas/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/darribas/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1376367312,
#     'node_id': 'MDU6TGFiZWwxMzc2MzY3MzEy',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/docs',
#     'name': 'docs',
#     'color': 'ffc8b2',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-02-01T08:27:07Z',
#   'updated_at': '2021-02-02T03:07:42Z',
#   'closed_at': '2021-02-02T03:07:42Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/387',
#    'html_url': 'https://github.com/pysal/libpysal/pull/387',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/387.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/387.patch'},
#   'body': 'This PR has a build of the docs created by:\r\n\r\n```shell\r\ncd docsrc\r\nmake build\r\nmake sync\r\n```\r\n\r\nI _think_ this is what was expected, but happy to amend.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/386',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/386/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/386/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/386/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/386',
#   'id': 797809057,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY0NzI2OTIw',
#   'number': 386,
#   'title': 'bump version',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-31T20:52:11Z',
#   'updated_at': '2021-01-31T23:17:39Z',
#   'closed_at': '2021-01-31T23:17:39Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/386',
#    'html_url': 'https://github.com/pysal/libpysal/pull/386',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/386.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/386.patch'},
#   'body': '',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/385',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/385/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/385/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/385/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/385',
#   'id': 797759117,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY0NjkxMTc2',
#   'number': 385,
#   'title': 'Adding raster interface to docs API + notebooks',
#   'user': {'login': 'darribas',
#    'id': 417363,
#    'node_id': 'MDQ6VXNlcjQxNzM2Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/417363?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/darribas',
#    'html_url': 'https://github.com/darribas',
#    'followers_url': 'https://api.github.com/users/darribas/followers',
#    'following_url': 'https://api.github.com/users/darribas/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/darribas/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/darribas/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/darribas/subscriptions',
#    'organizations_url': 'https://api.github.com/users/darribas/orgs',
#    'repos_url': 'https://api.github.com/users/darribas/repos',
#    'events_url': 'https://api.github.com/users/darribas/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/darribas/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-01-31T17:05:22Z',
#   'updated_at': '2021-01-31T20:14:53Z',
#   'closed_at': '2021-01-31T20:14:53Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/385',
#    'html_url': 'https://github.com/pysal/libpysal/pull/385',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/385.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/385.patch'},
#   'body': "This PR adds to the API docs and the notebooks folder for docs documentation from the GSoC'20 developed by @MgeeeeK (supervised by @slumnitz and myself @darribas ).\r\n\r\n@sjsrey , I _think_ this is all you mentioned, plus a little blurb for the release. Maybe the following could work?\r\n\r\n> Thanks to the Google Summer of Code 2020 led by Mragank Shekhar ([`@MgeeeeK`](https://github.com/MgeeeeK), we have built an interface with `xarray` that allows you to create spatial weights matrices from `xarray.DataArray` objects. This means it is possible to build a weights matrix from raster data. We are using `numba` and multi-core where possible so the implementation is performant and scalable within memory limits. Current weights supported include:\r\n>\r\n> - `libpysal.weights.Rook.from_xarray`\r\n> - `libpysal.weights.Queen.from_xarray` \r\n>\r\n> In addition, the following methods have been added and are exposed to end users:\r\n>\r\n> - [RECOMMENDED] `da2WSP`, to build a thin weights matrix (`WSP`) from a `xarray.DataArray`\r\n> - `da2W`, to build a weights matrix from a `xarray.DataArray`\r\n> - [RECOMMENDED] `wsp2da`, to reconstruct a `xarray.DataArray` object from a thin weights matrix and a `pandas.Series` (e.g. with `mapclassify` or `esda.Moran_Local` outcomes\r\n> - `w2da`, to reconstruct a `xarray.DataArray` object from a weights matrix and a `pandas.Series` (e.g. with `mapclassify` or `esda.Moran_Local` outcomes\r\n> - `testDataArray`, to generate a toy `xarray.DataArray` object for testing purposes.\r\n\r\n@MgeeeeK / @slumnitz please chip in if you miss something or would like to change/edit any aspect.\r\n\r\nPlease do let us know if there is anything else we need to add.",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/384',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/384/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/384/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/384/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/384',
#   'id': 797221856,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY0MjY4OTY0',
#   'number': 384,
#   'title': '[Doc]: Update raster example notebook and docstrings',
#   'user': {'login': 'MgeeeeK',
#    'id': 40512095,
#    'node_id': 'MDQ6VXNlcjQwNTEyMDk1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40512095?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MgeeeeK',
#    'html_url': 'https://github.com/MgeeeeK',
#    'followers_url': 'https://api.github.com/users/MgeeeeK/followers',
#    'following_url': 'https://api.github.com/users/MgeeeeK/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MgeeeeK/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MgeeeeK/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MgeeeeK/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MgeeeeK/orgs',
#    'repos_url': 'https://api.github.com/users/MgeeeeK/repos',
#    'events_url': 'https://api.github.com/users/MgeeeeK/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MgeeeeK/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-01-29T21:35:21Z',
#   'updated_at': '2021-01-31T16:37:06Z',
#   'closed_at': '2021-01-31T16:37:06Z',
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/384',
#    'html_url': 'https://github.com/pysal/libpysal/pull/384',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/384.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/384.patch'},
#   'body': 'This pr updates the doc string examples and example notebook which were left after adding `id_order` changes ([libpysal#383](https://github.com/pysal/libpysal/pull/383))',
#   'performed_via_github_app': None}]

# %%
lps[0]
# Out:
# {'url': 'https://api.github.com/repos/pysal/libpysal/issues/421',
#  'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#  'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/421/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/421/comments',
#  'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/421/events',
#  'html_url': 'https://github.com/pysal/libpysal/pull/421',
#  'id': 948081892,
#  'node_id': 'MDExOlB1bGxSZXF1ZXN0NjkyOTcxMzkw',
#  'number': 421,
#  'title': 'update Codecov action: major version only',
#  'user': {'login': 'jGaboardi',
#   'id': 8590583,
#   'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jGaboardi',
#   'html_url': 'https://github.com/jGaboardi',
#   'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#   'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#   'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#   'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [{'id': 2181405394,
#    'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzk0',
#    'url': 'https://api.github.com/repos/pysal/libpysal/labels/github_actions',
#    'name': 'github_actions',
#    'color': '000000',
#    'default': False,
#    'description': 'Pull requests that update Github_actions code'}],
#  'state': 'closed',
#  'locked': False,
#  'assignee': {'login': 'jGaboardi',
#   'id': 8590583,
#   'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jGaboardi',
#   'html_url': 'https://github.com/jGaboardi',
#   'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#   'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#   'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#   'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'assignees': [{'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False}],
#  'milestone': None,
#  'comments': 0,
#  'created_at': '2021-07-19T22:39:27Z',
#  'updated_at': '2021-07-19T22:48:42Z',
#  'closed_at': '2021-07-19T22:48:42Z',
#  'author_association': 'MEMBER',
#  'active_lock_reason': None,
#  'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/421',
#   'html_url': 'https://github.com/pysal/libpysal/pull/421',
#   'diff_url': 'https://github.com/pysal/libpysal/pull/421.diff',
#   'patch_url': 'https://github.com/pysal/libpysal/pull/421.patch'},
#  'body': 'Hello! Please make sure to check all these boxes before submitting a Pull Request\r\n(PR). Once you have checked the boxes, feel free to remove all text except the\r\njustification in point 5. \r\n\r\n1. [ ] You have run tests on this submission locally using `pytest` on your changes. Continuous integration will be run on all PRs with [GitHub Actions](https://github.com/pysal/libpysal/blob/master/.github/workflows/unittests.yml), but it is good practice to test changes locally prior to a making a PR.\r\n2. [ ] This pull request is directed to the `pysal/master` branch.\r\n3. [ ] This pull introduces new functionality covered by\r\n   [docstrings](https://en.wikipedia.org/wiki/Docstring#Python) and\r\n   [unittests](https://docs.python.org/2/library/unittest.html)? \r\n4. [ ] You have [assigned a\r\n   reviewer](https://help.github.com/articles/assigning-issues-and-pull-requests-to-other-github-users/) and added relevant [labels](https://help.github.com/articles/applying-labels-to-issues-and-pull-requests/)\r\n5. [ ] The justification for this PR is: \r\n',
#  'performed_via_github_app': None}
