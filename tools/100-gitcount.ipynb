# %% [markdown]
# # PySAL Change Log Statistics

# %% [markdown]
# urllib3>=1.26
# python-dateutil<=2.8.0
# pytest
# pytest-cov
# coverage## Approach
# - get date of last gh release of each package -> github_released
# - get date of last pypi release of each package -> pypi_released
# - get data of last meta-release -> start_date
# - for each package
#   - get issues between start_date and package_released in master/main
#   - get pulls between start_date and package_released in master/main

# %%
from release_info import (issues_closed_since, packages,
                          is_pull_request,
                          sorted_by_field,
                          clone_defaults,
                          release_date,
                          start_date,
                          PYSALVER,
                          USER
                         )
import datetime

# %%
packages
# Out:
# ['libpysal',
#  'access',
#  'esda',
#  'giddy',
#  'inequality',
#  'pointpats',
#  'segregation',
#  'spaghetti',
#  'mgwr',
#  'momepy',
#  'spglm',
#  'spint',
#  'spreg',
#  'spvcm',
#  'tobler',
#  'mapclassify',
#  'splot',
#  'spopt']

# %%
packages.append('pysal')

# %%
clone_defaults(packages)
# Out:
# tmp/libpysal exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/access exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/esda exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/giddy exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/inequality exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/pointpats exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/segregation exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/spaghetti exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/mgwr exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/momepy exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/spglm exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/spint exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/spreg exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/spvcm exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/tobler exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/mapclassify exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/splot exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/spopt exists, git pull required
# Output:
#  Already up to date.
#
# Errors:
#
# tmp/pysal exists, git pull required
# Output:
#  Already up to date.
#
# Errors:

# %%
since = datetime.datetime.combine(start_date, datetime.time(0,0))
since
# Out:
# datetime.datetime(2024, 1, 31, 0, 0)

# %%
release_date
# Out:
# datetime.date(2024, 7, 14)

# %%
issues = {}
for package in packages:
    issues[package] = issues_closed_since(since, project=f'pysal/{package}')

# %%
pulls = {}
for package in packages:
    pulls[package] = issues_closed_since(since, project=f'pysal/{package}',
                                         pulls=True)

# %%
len(issues)
# Out:
# 19

# %%
len(pulls)
# Out:
# 19

# %%
import pickle 

pickle.dump( issues, open( "issues_closed.p", "wb" ) )

pickle.dump( pulls, open("pulls_closed.p", "wb"))

# %%
len(issues['libpysal'])
# Out:
# 64

# %%
lps = issues['libpysal']

# %%
lps
# Out:
# [{'url': 'https://api.github.com/repos/pysal/libpysal/issues/752',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/752',
#   'id': 2403526191,
#   'node_id': 'PR_kwDOBNuegM51HVlh',
#   'number': 752,
#   'title': 'ENH: add index_pairs to Graph',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186559,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTk=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/enhancement',
#     'name': 'enhancement',
#     'color': '84b6eb',
#     'default': True,
#     'description': None},
#    {'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-07-11T15:48:46Z',
#   'updated_at': '2024-07-12T16:05:35Z',
#   'closed_at': '2024-07-12T15:33:52Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/752',
#    'html_url': 'https://github.com/pysal/libpysal/pull/752',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/752.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/752.patch',
#    'merged_at': '2024-07-12T15:33:52Z'},
#   'body': 'This adds convenience property to extract two aligned indices of focal-neighbour pairs as suggested by @sjsrey in https://github.com/pysal/esda/pull/326#discussion_r1674214831. ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/752/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/746',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/746/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/746/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/746/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/746',
#   'id': 2398347239,
#   'node_id': 'PR_kwDOBNuegM5012lq',
#   'number': 746,
#   'title': 'BUG: fix categorical lag for custom index',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186557,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTc=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/bug',
#     'name': 'bug',
#     'color': 'ee0701',
#     'default': True,
#     'description': "functionality that: returns invalid, erroneous, or meaningless results; or doesn't work at all."},
#    {'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2024-07-09T14:14:10Z',
#   'updated_at': '2024-07-11T14:19:00Z',
#   'closed_at': '2024-07-11T14:14:25Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/746',
#    'html_url': 'https://github.com/pysal/libpysal/pull/746',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/746.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/746.patch',
#    'merged_at': '2024-07-11T14:14:25Z'},
#   'body': 'While doing #745 we have noticed that categorical lag works only for graphs based on default range index.\r\n\r\nThis fixes it.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/746/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/746/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/743',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/743/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/743/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/743/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/743',
#   'id': 2396480344,
#   'node_id': 'PR_kwDOBNuegM50vZv8',
#   'number': 743,
#   'title': 'BUG: fix handling of non-isolate self-weights of 0 and order preservation',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186557,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTc=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/bug',
#     'name': 'bug',
#     'color': 'ee0701',
#     'default': True,
#     'description': "functionality that: returns invalid, erroneous, or meaningless results; or doesn't work at all."},
#    {'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-07-08T20:13:10Z',
#   'updated_at': '2024-07-11T14:09:31Z',
#   'closed_at': '2024-07-11T14:09:31Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/743',
#    'html_url': 'https://github.com/pysal/libpysal/pull/743',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/743.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/743.patch',
#    'merged_at': '2024-07-11T14:09:31Z'},
#   'body': 'Work over in esda uncovered a series of bugs related to handling of self-weights with 0 weight which are **not** isolates at the same time. I hope that this fixes them all. They are all tested, either in their own or in related tests. Reverting each would cause CI to fail.\r\n\r\nThis is precisely the reason why I started doing the support of Graph in esda, in hope that it verifies that Graph works as intended.\r\n\r\nThis is required for https://github.com/pysal/esda/pull/293/ to pass, alongside #742.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/743/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/743/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/751',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/751/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/751/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/751/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/751',
#   'id': 2401238616,
#   'node_id': 'PR_kwDOBNuegM50_nZC',
#   'number': 751,
#   'title': 'adjust CI env name & add Graph to README',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1376367312,
#     'node_id': 'MDU6TGFiZWwxMzc2MzY3MzEy',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/docs',
#     'name': 'docs',
#     'color': 'ffc8b2',
#     'default': False,
#     'description': ''},
#    {'id': 2525923533,
#     'node_id': 'MDU6TGFiZWwyNTI1OTIzNTMz',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/ci',
#     'name': 'ci',
#     'color': 'ffc4dc',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-07-10T16:48:54Z',
#   'updated_at': '2024-07-10T19:37:34Z',
#   'closed_at': '2024-07-10T19:37:31Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/751',
#    'html_url': 'https://github.com/pysal/libpysal/pull/751',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/751.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/751.patch',
#    'merged_at': '2024-07-10T19:37:31Z'},
#   'body': 'This PR:\r\n* resolves #749 \r\n* resolves #750 ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/751/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/751/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/750',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/750/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/750/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/750/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/750',
#   'id': 2401220851,
#   'node_id': 'I_kwDOBNuegM6PH7jz',
#   'number': 750,
#   'title': 'update README with mention of `Graph`',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1376367312,
#     'node_id': 'MDU6TGFiZWwxMzc2MzY3MzEy',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/docs',
#     'name': 'docs',
#     'color': 'ffc8b2',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-10T16:38:08Z',
#   'updated_at': '2024-07-10T19:37:32Z',
#   'closed_at': '2024-07-10T19:37:32Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '* update README with mention of `Graph`\r\n* https://github.com/pysal/pysal/pull/1331',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/750/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/750/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/749',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/749/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/749/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/749/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/749',
#   'id': 2400838170,
#   'node_id': 'I_kwDOBNuegM6PGeIa',
#   'number': 749,
#   'title': 'update CI env naming conventions',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2525923533,
#     'node_id': 'MDU6TGFiZWwyNTI1OTIzNTMz',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/ci',
#     'name': 'ci',
#     'color': 'ffc4dc',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'sjsrey',
#     'id': 118042,
#     'node_id': 'MDQ6VXNlcjExODA0Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sjsrey',
#     'html_url': 'https://github.com/sjsrey',
#     'followers_url': 'https://api.github.com/users/sjsrey/followers',
#     'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#     'repos_url': 'https://api.github.com/users/sjsrey/repos',
#     'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#     'type': 'User',
#     'site_admin': False},
#    {'login': 'knaaptime',
#     'id': 4213368,
#     'node_id': 'MDQ6VXNlcjQyMTMzNjg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/4213368?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/knaaptime',
#     'html_url': 'https://github.com/knaaptime',
#     'followers_url': 'https://api.github.com/users/knaaptime/followers',
#     'following_url': 'https://api.github.com/users/knaaptime/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/knaaptime/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/knaaptime/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/knaaptime/subscriptions',
#     'organizations_url': 'https://api.github.com/users/knaaptime/orgs',
#     'repos_url': 'https://api.github.com/users/knaaptime/repos',
#     'events_url': 'https://api.github.com/users/knaaptime/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/knaaptime/received_events',
#     'type': 'User',
#     'site_admin': False},
#    {'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False},
#    {'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-07-10T13:53:43Z',
#   'updated_at': '2024-07-10T19:37:32Z',
#   'closed_at': '2024-07-10T19:37:32Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'https://github.com/pysal/esda/issues/316#issue-2399192651\r\n\r\n* `...-min` -- minimal dependencies -- only hard requirements -- "no optional"\r\n* `...-oldest` -- pinned to oldest supported Python version & packages\r\n* `...-latest` -- no pins (accept Python version) for environment dependencies\r\n* `...-dev` -- fetching bleeding edge versions of dependencies, either from nightly PyPI or directly from GitHub\r\n* others\r\n   * any other tags should come before the 4 above, e.g. in [`esda`](https://github.com/pysal/esda/tree/main/ci) we have `312-dev.yaml`, `312-numba-latest.yaml`, `312-numba-dev.yaml`\r\n\r\nMoving forward we should try to stick with these conventions in all federation packages and modify existing structures as needed.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/749/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/749/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/534',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/534/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/534/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/534/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/534',
#   'id': 1809481773,
#   'node_id': 'I_kwDOBNuegM5r2oAt',
#   'number': 534,
#   'title': 'Weights sprint planning',
#   'user': {'login': 'ljwolf',
#    'id': 2250995,
#    'node_id': 'MDQ6VXNlcjIyNTA5OTU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2250995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ljwolf',
#    'html_url': 'https://github.com/ljwolf',
#    'followers_url': 'https://api.github.com/users/ljwolf/followers',
#    'following_url': 'https://api.github.com/users/ljwolf/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ljwolf/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ljwolf/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ljwolf/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ljwolf/orgs',
#    'repos_url': 'https://api.github.com/users/ljwolf/repos',
#    'events_url': 'https://api.github.com/users/ljwolf/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ljwolf/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 59,
#   'created_at': '2023-07-18T08:55:38Z',
#   'updated_at': '2024-07-10T16:28:33Z',
#   'closed_at': '2024-07-10T16:28:33Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "I'm starting this thread to begin discussions about the upcoming weights sprint. The current experimental implementation is in the [`geographs` branch, the `weights/experimental` module](https://github.com/pysal/libpysal/tree/geographs/libpysal/weights/experimental). The `ROADMAP.md` will need updating... ",
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/534/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/534/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/444',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/444/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/444/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/444/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/444',
#   'id': 1105926437,
#   'node_id': 'I_kwDOBNuegM5B6xkl',
#   'number': 444,
#   'title': 'Does release GHA work?',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 7,
#   'created_at': '2022-01-17T14:28:40Z',
#   'updated_at': '2024-07-10T16:27:42Z',
#   'closed_at': '2024-07-10T16:27:42Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'I am not sure if the recent release GHA workflow is able to upload to PyPI. See the archive and compare to GitHub releases - https://pypi.org/project/libpysal/#history. \r\n\r\ncc @jGaboardi ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/444/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/444/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/315',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/315/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/315/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/315/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/315',
#   'id': 652458590,
#   'node_id': 'MDU6SXNzdWU2NTI0NTg1OTA=',
#   'number': 315,
#   'title': 'scikit-geometry?',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1685673930,
#     'node_id': 'MDU6TGFiZWwxNjg1NjczOTMw',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/cg',
#     'name': 'cg',
#     'color': '4363cc',
#     'default': False,
#     'description': ''},
#    {'id': 1768401718,
#     'node_id': 'MDU6TGFiZWwxNzY4NDAxNzE4',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/discussion',
#     'name': 'discussion',
#     'color': '0e3075',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2020-07-07T16:28:23Z',
#   'updated_at': '2024-07-10T16:26:23Z',
#   'closed_at': '2024-07-10T16:26:23Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Putting this here for a bookmark / to start a discussion for potential to adopt more robust computational geometry solutions.\r\n\r\n* [`scikit-geometry`](https://github.com/scikit-geometry/scikit-geometry)\r\n* [SciPy 2020 talk](https://www.youtube.com/watch?v=LsgXJTK4OsU&list=PLYx7XA2nY5GfhekhCPLpA0NImFm2wNvSD&index=7&t=0s)\r\n\r\n\r\n\r\nSee also pysal/pysal#1164 (`spatialpandas`)',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/315/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/315/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/747',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/747/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/747/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/747/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/747',
#   'id': 2398421741,
#   'node_id': 'PR_kwDOBNuegM502HDw',
#   'number': 747,
#   'title': 'ensure that Graph._repr_ fits to 80 characters',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5816707490,
#     'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#     'name': 'graph',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2024-07-09T14:47:33Z',
#   'updated_at': '2024-07-09T15:26:42Z',
#   'closed_at': '2024-07-09T15:24:50Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/747',
#    'html_url': 'https://github.com/pysal/libpysal/pull/747',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/747.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/747.patch',
#    'merged_at': '2024-07-09T15:24:50Z'},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/747/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/747/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/745',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
# ...
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'martinfleis',
#     'id': 36797143,
#     'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/martinfleis',
#     'html_url': 'https://github.com/martinfleis',
#     'followers_url': 'https://api.github.com/users/martinfleis/followers',
#     'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#     'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#     'repos_url': 'https://api.github.com/users/martinfleis/repos',
#     'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-07T15:26:35Z',
#   'updated_at': '2024-02-07T15:48:05Z',
#   'closed_at': '2024-02-07T15:43:30Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/686',
#    'html_url': 'https://github.com/pysal/libpysal/pull/686',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/686.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/686.patch',
#    'merged_at': '2024-02-07T15:43:29Z'},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/686/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/686/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/684',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/684/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/684/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/684/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/684',
#   'id': 2118110110,
#   'node_id': 'I_kwDOBNuegM5-P8ue',
#   'number': 684,
#   'title': "ImportError: cannot import name 'np' from 'libpysal.common' ",
#   'user': {'login': 'wsqstar',
#    'id': 24500520,
#    'node_id': 'MDQ6VXNlcjI0NTAwNTIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24500520?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wsqstar',
#    'html_url': 'https://github.com/wsqstar',
#    'followers_url': 'https://api.github.com/users/wsqstar/followers',
#    'following_url': 'https://api.github.com/users/wsqstar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wsqstar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wsqstar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wsqstar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wsqstar/orgs',
#    'repos_url': 'https://api.github.com/users/wsqstar/repos',
#    'events_url': 'https://api.github.com/users/wsqstar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wsqstar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-05T09:52:30Z',
#   'updated_at': '2024-02-05T09:59:13Z',
#   'closed_at': '2024-02-05T09:59:12Z',
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '# Platform information:\r\nLast updated: 2024-02-05T17:05:56.848677+08:00\r\n\r\nPython implementation: CPython\r\nPython version       : 3.12.0\r\nIPython version      : 8.21.0\r\n\r\nCompiler    : GCC 11.2.0\r\nOS          : Linux\r\nRelease     : 5.15.133.1-microsoft-standard-WSL2\r\nMachine     : x86_64\r\nProcessor   : x86_64\r\nCPU cores   : 12\r\nArchitecture: 64bit\r\n\r\n- SciPy version:1.11.4\r\n- NumPy version:1.26.3\r\n\r\nWhen following the https://pysal.org/spopt/notebooks/p-median.html\r\nI tried：\r\n\r\n```python\r\nimport geopandas\r\nimport matplotlib.pyplot as plt\r\nfrom matplotlib.patches import Patch\r\nimport matplotlib.lines as mlines\r\nimport numpy\r\nimport pulp\r\nimport shapely\r\nimport spopt\r\nfrom spopt.locate import PMedian, simulated_geo_points\r\n\r\nimport warnings\r\nwith warnings.catch_warnings():\r\n    warnings.simplefilter("ignore")\r\n    # ignore deprecation warning - GH pysal/spaghetti#649\r\n    import spaghetti\r\n\r\n%watermark -w\r\n%watermark -iv\r\n```\r\nHowever：\r\n\r\n---------------------------------------------------------------------------\r\nImportError                               Traceback (most recent call last)\r\nCell In[7], [line 15](vscode-notebook-cell:?execution_count=7&line=15)\r\n     [13](vscode-notebook-cell:?execution_count=7&line=13)     warnings.simplefilter("ignore")\r\n     [14](vscode-notebook-cell:?execution_count=7&line=14)     # ignore deprecation warning - GH pysal/spaghetti#649\r\n---> [15](vscode-notebook-cell:?execution_count=7&line=15)     import spaghetti\r\n     [17](vscode-notebook-cell:?execution_count=7&line=17) get_ipython().run_line_magic(\'watermark\', \'-w\')\r\n     [18](vscode-notebook-cell:?execution_count=7&line=18) get_ipython().run_line_magic(\'watermark\', \'-iv\')\r\n\r\nFile [~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:7](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:7)\r\n      [1](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:1) __version__ = "1.6.2"\r\n      [3](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:3) """\r\n      [4](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:4) # `spaghetti` --- Spatial Graphs: Networks, Topology, & Inference\r\n      [5](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:5) """\r\n----> [7](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:7) from .network import Network, PointPattern, SimulatedPointPattern\r\n      [8](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:8) from .network import extract_component, spanning_tree\r\n      [9](https://vscode-remote+wsl-002bubuntu-002d22-002e04.vscode-resource.vscode-cdn.net/home/myubuntu/shiqi/dev/github/work/SC-RA-ShiqiWang/Dev/2SO4SAI/~/miniconda3/envs/py312/lib/python3.12/site-packages/spaghetti/__init__.py:9) fro ...
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/684/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/684/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'completed'},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/683',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/683/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/683/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/683/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/683',
#   'id': 2111188708,
#   'node_id': 'PR_kwDOBNuegM5loRly',
#   'number': 683,
#   'title': 'Bump codecov/codecov-action from 3 to 4',
#   'user': {'login': 'dependabot[bot]',
#    'id': 49699333,
#    'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#    'html_url': 'https://github.com/apps/dependabot',
#    'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#    'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#    'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#    'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#    'type': 'Bot',
#    'site_admin': False},
#   'labels': [{'id': 2181405393,
#     'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzkz',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/dependencies',
#     'name': 'dependencies',
#     'color': '0366d6',
#     'default': False,
#     'description': 'Pull requests that update a dependency file'},
#    {'id': 2181405394,
#     'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzk0',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/github_actions',
#     'name': 'github_actions',
#     'color': '000000',
#     'default': False,
#     'description': 'Pull requests that update Github_actions code'}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-01-31T23:53:57Z',
#   'updated_at': '2024-02-01T14:18:40Z',
#   'closed_at': '2024-02-01T14:18:36Z',
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/683',
#    'html_url': 'https://github.com/pysal/libpysal/pull/683',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/683.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/683.patch',
#    'merged_at': '2024-02-01T14:18:36Z'},
#   'body': 'Bumps [codecov/codecov-action](https://github.com/codecov/codecov-action) from 3 to 4.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/codecov/codecov-action/releases">codecov/codecov-action\'s releases</a>.</em></p>\n<blockquote>\n<h2>v4.0.0</h2>\n<p>v4 of the Codecov Action uses the <a href="https://docs.codecov.com/docs/the-codecov-cli">CLI</a> as the underlying upload. The CLI has helped to power new features including local upload, the global upload token, and new upcoming features.</p>\n<h2>Breaking Changes</h2>\n<ul>\n<li>The Codecov Action runs as a <code>node20</code> action due to <code>node16</code> deprecation. See <a href="https://github.blog/changelog/2023-09-22-github-actions-transitioning-from-node-16-to-node-20/">this post from GitHub</a> on how to migrate.</li>\n<li>Tokenless uploading is unsupported. However, PRs made from forks to the upstream public repos will support tokenless (e.g. contributors to OS projects do not need the upstream repo\'s Codecov token). This <a href="https://docs.codecov.com/docs/adding-the-codecov-token#github-actions">doc</a> shows instructions on how to add the Codecov token.</li>\n<li>OS platforms have been added, though some may not be automatically detected. To see a list of platforms, see our <a href="https://cli.codecov.io">CLI download page</a></li>\n<li>Various arguments to the Action have been changed. Please be aware that the arguments match with the CLI\'s needs</li>\n</ul>\n<p><code>v3</code> versions and below will not have access to CLI features (e.g. global upload token, ATS).</p>\n<h2>What\'s Changed</h2>\n<ul>\n<li>build(deps): bump openpgp from 5.8.0 to 5.9.0 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/985">codecov/codecov-action#985</a></li>\n<li>build(deps): bump actions/checkout from 3.0.0 to 3.5.3 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1000">codecov/codecov-action#1000</a></li>\n<li>build(deps): bump ossf/scorecard-action from 2.1.3 to 2.2.0 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1006">codecov/codecov-action#1006</a></li>\n<li>build(deps): bump tough-cookie from 4.0.0 to 4.1.3 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1013">codecov/codecov-action#1013</a></li>\n<li>build(deps-dev): bump word-wrap from 1.2.3 to 1.2.4 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1024">codecov/codecov-action#1024</a></li>\n<li>build(deps): bump node-fetch from 3.3.1 to 3.3.2 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1031">codecov/codecov-action#1031</a></li>\n<li>build(deps-dev): bump <code>@\u200btypes/node</code> from 20.1.4 to 20.4.5 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1032">codecov/codecov-action#1032</a></li>\n<li>build(deps): bump github/codeql-action from 1.0.26 to 2.21.2 by <a href="https://github.com/dependabot"><code>@\u200bdependabot</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/1033">codecov/codecov-action#1033</a></li>\n<li>build commit,report and upload args based on codecovcli by <a href="https://github.com/dana-yaish"><code>@\u200bdana-yaish</code></a> in <a href="https://redirect.github.com/codecov/codecov-action/pull/943">codecov/codecov-action#943</a></li>\n<li>build(deps-dev): bump <code>@\u200btypes/node</code> from 20.4.5 to 20.5.3 by <a href="https ...
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/683/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/683/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
lps[0]
# Out:
# {'url': 'https://api.github.com/repos/pysal/libpysal/issues/752',
#  'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#  'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/comments',
#  'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/events',
#  'html_url': 'https://github.com/pysal/libpysal/pull/752',
#  'id': 2403526191,
#  'node_id': 'PR_kwDOBNuegM51HVlh',
#  'number': 752,
#  'title': 'ENH: add index_pairs to Graph',
#  'user': {'login': 'martinfleis',
#   'id': 36797143,
#   'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/martinfleis',
#   'html_url': 'https://github.com/martinfleis',
#   'followers_url': 'https://api.github.com/users/martinfleis/followers',
#   'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#   'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#   'repos_url': 'https://api.github.com/users/martinfleis/repos',
#   'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [{'id': 536186559,
#    'node_id': 'MDU6TGFiZWw1MzYxODY1NTk=',
#    'url': 'https://api.github.com/repos/pysal/libpysal/labels/enhancement',
#    'name': 'enhancement',
#    'color': '84b6eb',
#    'default': True,
#    'description': None},
#   {'id': 5816707490,
#    'node_id': 'LA_kwDOBNuegM8AAAABWrPpog',
#    'url': 'https://api.github.com/repos/pysal/libpysal/labels/graph',
#    'name': 'graph',
#    'color': 'd4c5f9',
#    'default': False,
#    'description': ''}],
#  'state': 'closed',
#  'locked': False,
#  'assignee': {'login': 'martinfleis',
#   'id': 36797143,
#   'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/martinfleis',
#   'html_url': 'https://github.com/martinfleis',
#   'followers_url': 'https://api.github.com/users/martinfleis/followers',
#   'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#   'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#   'repos_url': 'https://api.github.com/users/martinfleis/repos',
#   'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'assignees': [{'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False}],
#  'milestone': None,
#  'comments': 1,
#  'created_at': '2024-07-11T15:48:46Z',
#  'updated_at': '2024-07-12T16:05:35Z',
#  'closed_at': '2024-07-12T15:33:52Z',
#  'author_association': 'MEMBER',
#  'active_lock_reason': None,
#  'draft': False,
#  'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/752',
#   'html_url': 'https://github.com/pysal/libpysal/pull/752',
#   'diff_url': 'https://github.com/pysal/libpysal/pull/752.diff',
#   'patch_url': 'https://github.com/pysal/libpysal/pull/752.patch',
#   'merged_at': '2024-07-12T15:33:52Z'},
#  'body': 'This adds convenience property to extract two aligned indices of focal-neighbour pairs as suggested by @sjsrey in https://github.com/pysal/esda/pull/326#discussion_r1674214831. ',
#  'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/752/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/752/timeline',
#  'performed_via_github_app': None,
#  'state_reason': None}
