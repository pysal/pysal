# %% [markdown]
# # PySAL Change Log Statistics

# %% [markdown]
# urllib3>=1.26
# python-dateutil<=2.8.0
# pytest
# pytest-cov
# coverage## Approach
# - get date of last gh release of each package -> github_released
# - get date of last pypi release of each package -> pypi_released
# - get data of last meta-release -> start_date
# - for each package
#   - get issues between start_date and package_released in master/main
#   - get pulls between start_date and package_released in master/main

# %%
from release_info import (issues_closed_since, packages,
                          is_pull_request,
                          sorted_by_field,
                          clone_defaults
                         )
import datetime

# %%
packages
# Out:
# ['libpysal',
#  'access',
#  'esda',
#  'giddy',
#  'inequality',
#  'pointpats',
#  'segregation',
#  'spaghetti',
#  'mgwr',
#  'momepy',
#  'spglm',
#  'spint',
#  'spreg',
#  'spvcm',
#  'tobler',
#  'mapclassify',
#  'splot',
#  'spopt']

# %%
packages.append('pysal') # add meta package

# %%
clone_defaults(packages)
# Out:
# git clone --branch master https://github.com/pysal/libpysal.git tmp/libpysal
# git clone --branch master https://github.com/pysal/access.git tmp/access
# git clone --branch master https://github.com/pysal/esda.git tmp/esda
# git clone --branch master https://github.com/pysal/giddy.git tmp/giddy
# git clone --branch master https://github.com/pysal/inequality.git tmp/inequality
# git clone --branch master https://github.com/pysal/pointpats.git tmp/pointpats
# git clone --branch master https://github.com/pysal/segregation.git tmp/segregation
# git clone --branch main https://github.com/pysal/spaghetti.git tmp/spaghetti
# git clone --branch master https://github.com/pysal/mgwr.git tmp/mgwr
# git clone --branch main https://github.com/pysal/momepy.git tmp/momepy
# git clone --branch master https://github.com/pysal/spglm.git tmp/spglm
# git clone --branch master https://github.com/pysal/spint.git tmp/spint
# git clone --branch master https://github.com/pysal/spreg.git tmp/spreg
# git clone --branch master https://github.com/pysal/spvcm.git tmp/spvcm
# git clone --branch master https://github.com/pysal/tobler.git tmp/tobler
# git clone --branch master https://github.com/pysal/mapclassify.git tmp/mapclassify
# git clone --branch main https://github.com/pysal/splot.git tmp/splot
# git clone --branch main https://github.com/pysal/spopt.git tmp/spopt
# git clone --branch master https://github.com/pysal/pysal.git tmp/pysal

# %%
release_date = '2022-01-31'
start_date = '2021-07-31'
since_date = '--since="{start}"'.format(start=start_date)
since_date
since = datetime.datetime.strptime(start_date+" 0:0:0", "%Y-%m-%d %H:%M:%S")
since
# Out:
# datetime.datetime(2021, 7, 31, 0, 0)

# %%
issues = {}
for package in packages:
    issues[package] = issues_closed_since(since, project=f'pysal/{package}')

# %%
pulls = {}
for package in packages:
    pulls[package] = issues_closed_since(since, project=f'pysal/{package}',
                                         pulls=True)

# %%
len(issues)
# Out:
# 19

# %%
len(pulls)
# Out:
# 19

# %%
import pickle 

pickle.dump( issues, open( "issues_closed.p", "wb" ) )

pickle.dump( pulls, open("pulls_closed.p", "wb"))

# %%
len(issues['libpysal'])
# Out:
# 25

# %%
lps = issues['libpysal']

# %%
lps
# Out:
# [{'url': 'https://api.github.com/repos/pysal/libpysal/issues/450',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/450',
#   'id': 1111706369,
#   'node_id': 'PR_kwDOBNuegM4xcwcb',
#   'number': 450,
#   'title': 'DOCS: Gabriel and related enhancements',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-01-22T22:32:14Z',
#   'updated_at': '2022-01-23T00:30:49Z',
#   'closed_at': '2022-01-23T00:30:49Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/450',
#    'html_url': 'https://github.com/pysal/libpysal/pull/450',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/450.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/450.patch',
#    'merged_at': '2022-01-23T00:30:49Z'},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/450/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/449',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/449/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/449/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/449/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/449',
#   'id': 1111699669,
#   'node_id': 'PR_kwDOBNuegM4xcvI5',
#   'number': 449,
#   'title': 'DOC: Update docs for Gabriel and related enhancements',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-01-22T22:00:26Z',
#   'updated_at': '2022-01-22T22:28:08Z',
#   'closed_at': '2022-01-22T22:28:07Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/449',
#    'html_url': 'https://github.com/pysal/libpysal/pull/449',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/449.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/449.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/449/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/449/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/448',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/448/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/448/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/448/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/448',
#   'id': 1111694116,
#   'node_id': 'PR_kwDOBNuegM4xcuE7',
#   'number': 448,
#   'title': 'Gabriel docs',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-01-22T21:34:47Z',
#   'updated_at': '2022-01-22T22:10:19Z',
#   'closed_at': '2022-01-22T21:59:09Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/448',
#    'html_url': 'https://github.com/pysal/libpysal/pull/448',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/448.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/448.patch',
#    'merged_at': None},
#   'body': 'This adds docs for #438 ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/448/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/448/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/438',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/438/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/438/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/438/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/438',
#   'id': 1029596996,
#   'node_id': 'PR_kwDOBNuegM4tWclc',
#   'number': 438,
#   'title': 'add gabriel weights and more performant voronoi generation',
#   'user': {'login': 'ljwolf',
#    'id': 2250995,
#    'node_id': 'MDQ6VXNlcjIyNTA5OTU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2250995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ljwolf',
#    'html_url': 'https://github.com/ljwolf',
#    'followers_url': 'https://api.github.com/users/ljwolf/followers',
#    'following_url': 'https://api.github.com/users/ljwolf/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ljwolf/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ljwolf/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ljwolf/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ljwolf/orgs',
#    'repos_url': 'https://api.github.com/users/ljwolf/repos',
#    'events_url': 'https://api.github.com/users/ljwolf/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ljwolf/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1685673071,
#     'node_id': 'MDU6TGFiZWwxNjg1NjczMDcx',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/weights',
#     'name': 'weights',
#     'color': 'e2ab73',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 17,
#   'created_at': '2021-10-18T21:06:25Z',
#   'updated_at': '2022-01-22T21:35:24Z',
#   'closed_at': '2022-01-22T21:35:23Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/438',
#    'html_url': 'https://github.com/pysal/libpysal/pull/438',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/438.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/438.patch',
#    'merged_at': '2022-01-22T21:35:23Z'},
#   'body': 'This adds a revised `numba`-accelerated version of the Voronoi constructor (which avoids building the Voronoi polygons explicitly and instead opts to work directly with the Delaunay graph) and implements a Gabriel graph constructor (*edit: and a relative neighborhood constructor*) based on the new Voronoi/Delaunay constructor. The Gabriel graph is a subset of the Delaunay triangulation where the circle whose diameter is edge *ij* contains no other point *k*.\r\n\r\n### The math for the Gabriel graph\r\n\r\nGiven the fast `QHull` Delaunay constructor, we can just start from the Delaunay triangulation and remove links *ij* if *k*, some other neighbor of *i*, is within the circle whose diameter is *ij*. \r\n\r\nTo do this, we first can say (by [Thales\' Theorem](https://en.wikipedia.org/wiki/Thales%27s_theorem)) that any triangle *ijk* with a side *ij* that is a circle diameter will be a *right* triangle when the non-diameter point *k* is *also* on the circle. This means that when *k* is *on the boundary* of the circle with *ij* as a diameter, then we have the Pythagorean relationship, *dij^2 = dik^2 + djk^2*. However, if *dij^2* is ever bigger than *dik^2 + djk^2*, then we know that triangle *ijk* is obtuse, and that *k* is "within" the circle whose diameter is *ij*. So, for focal *i* and each pair of neighbors *(j*,*k)*, prune Delaunay edge *ij* when *dij^2 > dik^2 + djk^2*. \r\n\r\nThis needs:\r\n- [ ] tests\r\n- [x] comparison with R\'s [gabrielgraph](https://r-spatial.github.io/spdep/reference/graphneigh.html)\r\n- [x] **decision**: if we use this graph constructor for Delaunay/Voronoi, it comes as about an order of magnitude speedup. But, it (a) cannot handle "clipping" the voronoi polygons to an arbitrary study extent (or, indeed, to a convex or alpha-hull) and (b) will then never be exactly equivalent to the Rook graph of a clipped Voronoi Diagram. But, this has the conceptual simplicity that it *only* converts the Delaunay triangulation into a graph, rather than building the voronoi cells, then clipping them, then constructing that Rook graph. So, input is needed on which we should use @sjsrey @martinfleis \r\n```\r\n        Old Voronoi: 0.83s\r\n        Raw Gabriel: 1.37s\r\n        Compile: 1.88s\r\n        New Delaunay: 0.04s\r\n        Ref Gabriel: 0.07s\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/438/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/438/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/442',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/442/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/442/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/442/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/442',
#   'id': 1081720359,
#   'node_id': 'PR_kwDOBNuegM4v7KT4',
#   'number': 442,
#   'title': 'ENH: Moving to appdirs for example storage',
#   'user': {'login': 'sjsrey',
#    'id': 118042,
#    'node_id': 'MDQ6VXNlcjExODA0Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sjsrey',
#    'html_url': 'https://github.com/sjsrey',
#    'followers_url': 'https://api.github.com/users/sjsrey/followers',
#    'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#    'repos_url': 'https://api.github.com/users/sjsrey/repos',
#    'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2021-12-16T03:07:47Z',
#   'updated_at': '2022-01-22T17:56:36Z',
#   'closed_at': '2022-01-22T15:24:59Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/442',
#    'html_url': 'https://github.com/pysal/libpysal/pull/442',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/442.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/442.patch',
#    'merged_at': '2022-01-22T15:24:59Z'},
#   'body': 'Using [appdirs](https://github.com/ActiveState/appdirs) to handle local storage of examples.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/442/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/442/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/443',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/443/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/443/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/443/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/443',
#   'id': 1096646741,
#   'node_id': 'PR_kwDOBNuegM4wrQMG',
#   'number': 443,
#   'title': 'MAINT: replace LooseVersion with packaging',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-01-07T20:27:58Z',
#   'updated_at': '2022-01-07T20:41:14Z',
#   'closed_at': '2022-01-07T20:39:54Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/443',
#    'html_url': 'https://github.com/pysal/libpysal/pull/443',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/443.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/443.patch',
#    'merged_at': '2022-01-07T20:39:54Z'},
#   'body': '`LooseVersion` is now deprecated, Python 3.10 warns about that. Using `packaging.version.Version` instead as suggested in the warning.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/443/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/443/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/349',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/349/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/349/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/349/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/349',
#   'id': 714968186,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDk3OTU4MTYz',
#   'number': 349,
#   'title': 'Format UserWarning string in W.to_adjlist',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1000808619,
#     'node_id': 'MDU6TGFiZWwxMDAwODA4NjE5',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/rough%20edge',
#     'name': 'rough edge',
#     'color': '5621dd',
#     'default': False,
#     'description': 'Something that\'s not a bug, but that gets in the way of "it just works."'},
#    {'id': 1685673071,
#     'node_id': 'MDU6TGFiZWwxNjg1NjczMDcx',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/weights',
#     'name': 'weights',
#     'color': 'e2ab73',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pysal/libpysal/milestones/5',
#    'html_url': 'https://github.com/pysal/libpysal/milestone/5',
#    'labels_url': 'https://api.github.com/repos/pysal/libpysal/milestones/5/labels',
#    'id': 7120527,
#    'node_id': 'MI_kwDOBNuegM4AbKaP',
#    'number': 5,
#    'title': 'next',
#    'description': None,
#    'creator': {'login': 'ljwolf',
#     'id': 2250995,
#     'node_id': 'MDQ6VXNlcjIyNTA5OTU=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/2250995?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ljwolf',
#     'html_url': 'https://github.com/ljwolf',
#     'followers_url': 'https://api.github.com/users/ljwolf/followers',
#     'following_url': 'https://api.github.com/users/ljwolf/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ljwolf/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ljwolf/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ljwolf/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ljwolf/orgs',
#     'repos_url': 'https://api.github.com/users/ljwolf/repos',
#     'events_url': 'https://api.github.com/users/ljwolf/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ljwolf/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1,
#    'closed_issues': 2,
#    'state': 'open',
#    'created_at': '2021-09-03T16:26:56Z',
#    'updated_at': '2021-12-10T12:46:56Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 5,
#   'created_at': '2020-10-05T16:01:46Z',
#   'updated_at': '2021-12-10T16:30:33Z',
#   'closed_at': '2021-12-10T12:46:56Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/349',
#    'html_url': 'https://github.com/pysal/libpysal/pull/349',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/349.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/349.patch',
#    'merged_at': None},
#   'body': 'Warning expects a number of islands, but the formatting is not there.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/349/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/349/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/285',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/285/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/285/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/285/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/285',
#   'id': 609172096,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDEwODA0NjQy',
#   'number': 285,
#   'title': 'remove non-coincident points correctly from knn weights',
#   'user': {'login': 'ljwolf',
#    'id': 2250995,
#    'node_id': 'MDQ6VXNlcjIyNTA5OTU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2250995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ljwolf',
#    'html_url': 'https://github.com/ljwolf',
#    'followers_url': 'https://api.github.com/users/ljwolf/followers',
#    'following_url': 'https://api.github.com/users/ljwolf/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ljwolf/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ljwolf/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ljwolf/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ljwolf/orgs',
#    'repos_url': 'https://api.github.com/users/ljwolf/repos',
#    'events_url': 'https://api.github.com/users/ljwolf/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ljwolf/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 536186557,
#     'node_id': 'MDU6TGFiZWw1MzYxODY1NTc=',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/bug',
#     'name': 'bug',
#     'color': 'ee0701',
#     'default': True,
#     'description': "functionality that: returns invalid, erroneous, or meaningless results; or doesn't work at all."},
#    {'id': 1685673071,
#     'node_id': 'MDU6TGFiZWwxNjg1NjczMDcx',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/weights',
#     'name': 'weights',
#     'color': 'e2ab73',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 8,
#   'created_at': '2020-04-29T15:59:41Z',
#   'updated_at': '2021-12-10T14:57:58Z',
#   'closed_at': '2021-12-10T14:57:57Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/285',
#    'html_url': 'https://github.com/pysal/libpysal/pull/285',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/285.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/285.patch',
#    'merged_at': '2021-12-10T14:57:57Z'},
#   'body': 'This fixes self neighbor issues by moving away from for loops in de-duplicating the neighbor lists. ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/285/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/285/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/439',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/439/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/439/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/439/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/439',
#   'id': 1034022635,
#   'node_id': 'PR_kwDOBNuegM4tknMF',
#   'number': 439,
#   'title': 'Bug fix for parallel execution environments',
#   'user': {'login': 'schmidtc',
#    'id': 1403099,
#    'node_id': 'MDQ6VXNlcjE0MDMwOTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1403099?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/schmidtc',
#    'html_url': 'https://github.com/schmidtc',
#    'followers_url': 'https://api.github.com/users/schmidtc/followers',
#    'following_url': 'https://api.github.com/users/schmidtc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/schmidtc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/schmidtc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/schmidtc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/schmidtc/orgs',
#    'repos_url': 'https://api.github.com/users/schmidtc/repos',
#    'events_url': 'https://api.github.com/users/schmidtc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/schmidtc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2021-10-23T00:12:47Z',
#   'updated_at': '2021-12-10T12:09:00Z',
#   'closed_at': '2021-12-10T12:08:44Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/439',
#    'html_url': 'https://github.com/pysal/libpysal/pull/439',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/439.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/439.patch',
#    'merged_at': '2021-12-10T12:08:43Z'},
#   'body': "1. [No] Don't have dev environment setup, but tested functionality locally.\r\n5. [Yes] The justification for this PR is: Have been hitting a rare bug here when deploying applications with many worker processes in a Kubernetes environment.  A bit of a race condition exists here where multiple workers attempt to create the directory but fail because another worker already created it, resulting in a crash loop.\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/439/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/439/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/429',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/429/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/429/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/429/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/429',
#   'id': 988046318,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzI3MDQxNjc5',
#   'number': 429,
#   'title': 'Use versioneer to manage __version__',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 8,
#   'created_at': '2021-09-03T19:22:17Z',
#   'updated_at': '2021-12-03T16:23:37Z',
#   'closed_at': '2021-09-11T21:17:34Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/429',
#    'html_url': 'https://github.com/pysal/libpysal/pull/429',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/429.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/429.patch',
#    'merged_at': '2021-09-11T21:17:34Z'},
#   'body': 'Following today\'s chat on using automatised way of `__version__` management, this adds `versioneer`-based implementation.\r\n\r\nIt is a pretty straightforward PR.\r\n\r\n1. install `versioneer`\r\n\r\n```\r\npip install versioneer\r\n```\r\n\r\n2. add `setup.cfg` with the following contents\r\n\r\n```\r\n[versioneer]\r\nVCS = git\r\nstyle = pep440\r\nversionfile_source = libpysal/_version.py\r\nversionfile_build = libpysal/_version.py\r\ntag_prefix = v\r\nparentdir_prefix = libpysal-\r\n```\r\n\r\nEach project should replace `lipbysal` with the relevant name here.\r\n\r\n3. Run versioneer from root folder\r\n\r\n```\r\nversioneer install .\r\n```\r\n\r\n4. edit `setup.py`\r\n\r\n**Remove** reading of version from `__init__`:\r\n```diff\r\n- # Get __version__ from libpysal/__init__.py without importing the package\r\n- # __version__ has to be defined in the first line\r\n- with open("libpysal/__init__.py", "r") as f:\r\n-     exec(f.readline())\r\n```\r\n\r\nImport versioneer and use it within `setup()`:\r\n\r\n```\r\nimport versioneer\r\n\r\n...\r\n\r\nsetup(\r\n    ...\r\n    version=versioneer.get_version(),\r\n    cmdclass=versioneer.get_cmdclass({"build_py": build_py}),  \r\n    ...)\r\n```\r\nI am wrapping existing `{"build_py": build_py}` in versioneer\'s one.\r\n\r\n5. Remove hardcoded `__version__` from `__init__.py`\r\n\r\nEverything else is automated. For details, see the changes in this PR.\r\n\r\nHow it works:\r\n```py\r\nIn [1]: import libpysal\r\n\r\nIn [2]: libpysal.__version__\r\nOut[2]: \'4.5.1.post2+23.gb400dc0e\'\r\n```\r\n\r\n`4.5.1.post2` is the latest tag, `23` is the number of commits since that tag, `gb400dc0e` is the ID of the latest commit.\r\n\r\n\r\nTo use it across pysal ecosystem, we will need to do the same in all packages and probably change some meta-package machinery that may expect `__version__` in a different way.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/429/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/429/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/437',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/437/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/437/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/437/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/437',
#   'id': 1019040797,
#   'node_id': 'PR_kwDOBNuegM4s11ux',
#   'number': 437,
#   'title': 'REF: update for shapely 2.0',
#   'user': {'login': 'martinfleis',
#    'id': 36797143,
#    'node_id': 'MDQ6VXNlcjM2Nzk3MTQz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36797143?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/martinfleis',
#    'html_url': 'https://github.com/martinfleis',
#    'followers_url': 'https://api.github.com/users/martinfleis/followers',
#    'following_url': 'https://api.github.com/users/martinfleis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/martinfleis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/martinfleis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/martinfleis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/martinfleis/orgs',
#    'repos_url': 'https://api.github.com/users/martinfleis/repos',
#    'events_url': 'https://api.github.com/users/martinfleis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/martinfleis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-10-06T19:23:12Z',
#   'updated_at': '2021-10-14T14:44:12Z',
#   'closed_at': '2021-10-13T16:12:59Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/437',
#    'html_url': 'https://github.com/pysal/libpysal/pull/437',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/437.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/437.patch',
#    'merged_at': '2021-10-13T16:12:59Z'},
#   'body': 'This PR adapts the code to the upcoming shapely 2.0, which in practice means eliminating deprecation warnings coming from shapely 1.8rc1.\r\n\r\nSee the migration guide for details - https://shapely.readthedocs.io/en/latest/migration.html. My guess is that we will have to do similar actions in other repositories as well.\r\n\r\nYou can install shapely 1.8rc1 from conda-forge:\r\n\r\n```\r\nmamba update -c conda-forge/label/shapely_dev shapely\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/437/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/437/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/434',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/434/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/434/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/434/events',
#   'html_url': 'https://github.com/pysal/libpysal/issues/434',
#   'id': 1004836286,
#   'node_id': 'I_kwDOBNuegM475JW-',
#   'number': 434,
#   'title': 'tools/gitcount with versioneer',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-22T22:41:36Z',
#   'updated_at': '2021-10-01T19:24:20Z',
#   'closed_at': '2021-10-01T19:24:20Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'In order to take advantage of using [`tools/gitcount.ipynb`](https://github.com/pysal/libpysal/blob/master/tools/gitcount.ipynb) with the newly adopted `versioneer`schema, the [version import cell](https://github.com/pysal/libpysal/blame/master/tools/gitcount.ipynb#L145-L148) must be split into two cells and changed from:\r\n\r\n```python\r\n# get __version__\r\nf = "../{package}/__init__.py".format(package=package_name)\r\nwith open(f, "r") as initfile:\r\n     exec(initfile.readline())\r\n```\r\n\r\nto:\r\n\r\n```python\r\n# get __version__\r\n%run ../libpysal/_version.py\r\n```\r\n```python\r\n__version__ = get_versions()["version"]\r\n```\r\n\r\nxref pysal/spaghetti#654',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/434/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/434/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/435',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/435/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/435/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/435/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/435',
#   'id': 1004839111,
#   'node_id': 'PR_kwDOBNuegM4sKYPi',
#   'number': 435,
#   'title': 'update version import in gitcount',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-09-22T22:47:25Z',
#   'updated_at': '2021-10-01T19:20:32Z',
#   'closed_at': '2021-10-01T19:20:05Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/435',
#    'html_url': 'https://github.com/pysal/libpysal/pull/435',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/435.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/435.patch',
#    'merged_at': '2021-10-01T19:20:05Z'},
#   'body': 'Addressing #434.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/435/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/435/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/321',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/321/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/321/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/321/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/321',
#   'id': 656788421,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDQ5MDIzMTgx',
#   'number': 321,
#   'title': 'represent islands as self-joins with zero weight in adjacency lists',
#   'user': {'login': 'ljwolf',
#    'id': 2250995,
#    'node_id': 'MDQ6VXNlcjIyNTA5OTU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2250995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ljwolf',
#    'html_url': 'https://github.com/ljwolf',
#    'followers_url': 'https://api.github.com/users/ljwolf/followers',
#    'following_url': 'https://api.github.com/users/ljwolf/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ljwolf/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ljwolf/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ljwolf/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ljwolf/orgs',
#    'repos_url': 'https://api.github.com/users/ljwolf/repos',
#    'events_url': 'https://api.github.com/users/ljwolf/events{/privacy}',
# ...
#   'active_lock_reason': None,
#   'body': '`test_lat2SW` breaking after `scipy 1.7.0` used in testing. Seems to be a change in [`scipy.sparse.dia`](https://github.com/scipy/scipy/commit/23aa0cbaff1754f02acf074006399ba2edede2ef#diff-8a57744fb65927efbe268b2d787bdb06d5b6d4c59a9aa67a924c002604a70460) \r\n\r\nSee [here](https://github.com/pysal/libpysal/pull/418#issuecomment-869232551) for more information.\r\n\r\nSkipping `test_lat2SW` with `scipy 1.7.0` for now.\r\n\r\n\r\nSee all so #420.',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/419/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/419/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/423',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/423/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/423/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/423/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/423',
#   'id': 972920030,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzE0NDQzOTMy',
#   'number': 423,
#   'title': 'use toarray in `W.full()`',
#   'user': {'login': 'knaaptime',
#    'id': 4213368,
#    'node_id': 'MDQ6VXNlcjQyMTMzNjg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4213368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/knaaptime',
#    'html_url': 'https://github.com/knaaptime',
#    'followers_url': 'https://api.github.com/users/knaaptime/followers',
#    'following_url': 'https://api.github.com/users/knaaptime/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/knaaptime/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/knaaptime/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/knaaptime/subscriptions',
#    'organizations_url': 'https://api.github.com/users/knaaptime/orgs',
#    'repos_url': 'https://api.github.com/users/knaaptime/repos',
#    'events_url': 'https://api.github.com/users/knaaptime/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/knaaptime/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 10,
#   'created_at': '2021-08-17T17:37:48Z',
#   'updated_at': '2021-08-31T11:21:43Z',
#   'closed_at': '2021-08-31T11:21:43Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/423',
#    'html_url': 'https://github.com/pysal/libpysal/pull/423',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/423.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/423.patch',
#    'merged_at': '2021-08-31T11:21:43Z'},
#   'body': "this uses the `toarray` method on a W's sparse matrix format to generate the dense matrix which is much faster than our manual approach",
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/423/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/423/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/426',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/426/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/426/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/426/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/426',
#   'id': 982952306,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzIyNjE2NzAz',
#   'number': 426,
#   'title': 'cast sw to csc and eliminate zeros',
#   'user': {'login': 'ljwolf',
#    'id': 2250995,
#    'node_id': 'MDQ6VXNlcjIyNTA5OTU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2250995?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ljwolf',
#    'html_url': 'https://github.com/ljwolf',
#    'followers_url': 'https://api.github.com/users/ljwolf/followers',
#    'following_url': 'https://api.github.com/users/ljwolf/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ljwolf/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ljwolf/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ljwolf/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ljwolf/orgs',
#    'repos_url': 'https://api.github.com/users/ljwolf/repos',
#    'events_url': 'https://api.github.com/users/ljwolf/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ljwolf/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2021-08-30T16:03:48Z',
#   'updated_at': '2021-08-31T10:52:26Z',
#   'closed_at': '2021-08-31T10:52:26Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/426',
#    'html_url': 'https://github.com/pysal/libpysal/pull/426',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/426.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/426.patch',
#    'merged_at': '2021-08-31T10:52:26Z'},
#   'body': 'Hello! Please make sure to check all these boxes before submitting a Pull Request\r\n(PR). Once you have checked the boxes, feel free to remove all text except the\r\njustification in point 5. \r\n\r\n1. [x] You have run tests on this submission locally using `pytest` on your changes. Continuous integration will be run on all PRs with [GitHub Actions](https://github.com/pysal/libpysal/blob/master/.github/workflows/unittests.yml), but it is good practice to test changes locally prior to a making a PR.\r\n2. [x] This pull request is directed to the `pysal/master` branch.\r\n3. [x] This pull introduces new functionality covered by\r\n   [docstrings](https://en.wikipedia.org/wiki/Docstring#Python) and\r\n   [unittests](https://docs.python.org/2/library/unittest.html)? \r\n4. [x] You have [assigned a\r\n   reviewer](https://help.github.com/articles/assigning-issues-and-pull-requests-to-other-github-users/) and added relevant [labels](https://help.github.com/articles/applying-labels-to-issues-and-pull-requests/)\r\n5. [x] The justification for this PR is: \r\n\r\nBug in `lat2SW` that does not remove structural zeros before returning the sparse matrix. ',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/426/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/426/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/425',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/425/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/425/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/425/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/425',
#   'id': 981679445,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzIxNjc5MDMx',
#   'number': 425,
#   'title': 'skip scipy 1.7.1 for in test_lat2SW',
#   'user': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1685677663,
#     'node_id': 'MDU6TGFiZWwxNjg1Njc3NjYz',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/tests',
#     'name': 'tests',
#     'color': '65f76a',
#     'default': False,
#     'description': ''},
#    {'id': 2181405393,
#     'node_id': 'MDU6TGFiZWwyMTgxNDA1Mzkz',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/dependencies',
#     'name': 'dependencies',
#     'color': '0366d6',
#     'default': False,
#     'description': 'Pull requests that update a dependency file'},
#    {'id': 2663620474,
#     'node_id': 'MDU6TGFiZWwyNjYzNjIwNDc0',
#     'url': 'https://api.github.com/repos/pysal/libpysal/labels/priority:%20high',
#     'name': 'priority: high',
#     'color': 'ADCA10',
#     'default': False,
#     'description': ''}],
#   'state': 'closed',
#   'locked': False,
#   'assignee': {'login': 'jGaboardi',
#    'id': 8590583,
#    'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jGaboardi',
#    'html_url': 'https://github.com/jGaboardi',
#    'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#    'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#    'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#    'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'jGaboardi',
#     'id': 8590583,
#     'node_id': 'MDQ6VXNlcjg1OTA1ODM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8590583?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jGaboardi',
#     'html_url': 'https://github.com/jGaboardi',
#     'followers_url': 'https://api.github.com/users/jGaboardi/followers',
#     'following_url': 'https://api.github.com/users/jGaboardi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jGaboardi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jGaboardi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jGaboardi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jGaboardi/orgs',
#     'repos_url': 'https://api.github.com/users/jGaboardi/repos',
#     'events_url': 'https://api.github.com/users/jGaboardi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jGaboardi/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-28T00:36:47Z',
#   'updated_at': '2021-08-29T14:22:16Z',
#   'closed_at': '2021-08-29T14:22:11Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/425',
#    'html_url': 'https://github.com/pysal/libpysal/pull/425',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/425.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/425.patch',
#    'merged_at': '2021-08-29T14:22:11Z'},
#   'body': 'This PR skips `test_lat2SW` for scipy 1.7.1, in addition to 1.7.0. We need to get tests passing again for now, but need to either figure out if we are doing something wrong in [`lat2SW`](https://github.com/pysal/libpysal/blob/master/libpysal/weights/util.py#L1169) or if a bug was introduced into `scipy` in scipy/scipy#14004.\r\n\r\nSee also:\r\n* #418 (this [comment](https://github.com/pysal/libpysal/issues/419#issuecomment-907535129))\r\n* #419 (this [comment](https://github.com/pysal/libpysal/issues/419#issuecomment-907535129))\r\n* #420\r\n* #423 (this [comment](https://github.com/pysal/libpysal/pull/423#issuecomment-904928037))',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/425/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/425/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pysal/libpysal/issues/422',
#   'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#   'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/422/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/422/comments',
#   'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/422/events',
#   'html_url': 'https://github.com/pysal/libpysal/pull/422',
#   'id': 972914009,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NzE0NDM4ODkx',
#   'number': 422,
#   'title': 'dense',
#   'user': {'login': 'knaaptime',
#    'id': 4213368,
#    'node_id': 'MDQ6VXNlcjQyMTMzNjg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4213368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/knaaptime',
#    'html_url': 'https://github.com/knaaptime',
#    'followers_url': 'https://api.github.com/users/knaaptime/followers',
#    'following_url': 'https://api.github.com/users/knaaptime/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/knaaptime/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/knaaptime/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/knaaptime/subscriptions',
#    'organizations_url': 'https://api.github.com/users/knaaptime/orgs',
#    'repos_url': 'https://api.github.com/users/knaaptime/repos',
#    'events_url': 'https://api.github.com/users/knaaptime/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/knaaptime/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'closed',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-08-17T17:29:56Z',
#   'updated_at': '2021-08-17T17:30:27Z',
#   'closed_at': '2021-08-17T17:30:27Z',
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/422',
#    'html_url': 'https://github.com/pysal/libpysal/pull/422',
#    'diff_url': 'https://github.com/pysal/libpysal/pull/422.diff',
#    'patch_url': 'https://github.com/pysal/libpysal/pull/422.patch',
#    'merged_at': None},
#   'body': '- initial draft of network weights\n- use toarray\n',
#   'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/422/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/422/timeline',
#   'performed_via_github_app': None}]

# %%
lps[0]
# Out:
# {'url': 'https://api.github.com/repos/pysal/libpysal/issues/450',
#  'repository_url': 'https://api.github.com/repos/pysal/libpysal',
#  'labels_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/comments',
#  'events_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/events',
#  'html_url': 'https://github.com/pysal/libpysal/pull/450',
#  'id': 1111706369,
#  'node_id': 'PR_kwDOBNuegM4xcwcb',
#  'number': 450,
#  'title': 'DOCS: Gabriel and related enhancements',
#  'user': {'login': 'sjsrey',
#   'id': 118042,
#   'node_id': 'MDQ6VXNlcjExODA0Mg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/118042?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sjsrey',
#   'html_url': 'https://github.com/sjsrey',
#   'followers_url': 'https://api.github.com/users/sjsrey/followers',
#   'following_url': 'https://api.github.com/users/sjsrey/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sjsrey/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sjsrey/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sjsrey/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sjsrey/orgs',
#   'repos_url': 'https://api.github.com/users/sjsrey/repos',
#   'events_url': 'https://api.github.com/users/sjsrey/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sjsrey/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'labels': [],
#  'state': 'closed',
#  'locked': False,
#  'assignee': None,
#  'assignees': [],
#  'milestone': None,
#  'comments': 1,
#  'created_at': '2022-01-22T22:32:14Z',
#  'updated_at': '2022-01-23T00:30:49Z',
#  'closed_at': '2022-01-23T00:30:49Z',
#  'author_association': 'MEMBER',
#  'active_lock_reason': None,
#  'draft': False,
#  'pull_request': {'url': 'https://api.github.com/repos/pysal/libpysal/pulls/450',
#   'html_url': 'https://github.com/pysal/libpysal/pull/450',
#   'diff_url': 'https://github.com/pysal/libpysal/pull/450.diff',
#   'patch_url': 'https://github.com/pysal/libpysal/pull/450.patch',
#   'merged_at': '2022-01-23T00:30:49Z'},
#  'body': None,
#  'reactions': {'url': 'https://api.github.com/repos/pysal/libpysal/issues/450/reactions',
#   'total_count': 0,
#   '+1': 0,
#   '-1': 0,
#   'laugh': 0,
#   'hooray': 0,
#   'confused': 0,
#   'heart': 0,
#   'rocket': 0,
#   'eyes': 0},
#  'timeline_url': 'https://api.github.com/repos/pysal/libpysal/issues/450/timeline',
#  'performed_via_github_app': None}
